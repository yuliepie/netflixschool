# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## path 설정

# %%
path = '../..'
# path = 
word_path = f'{path}/words/final_datasets'

# %% [markdown]
# ## 파일 불러오기

# %%
df = pd.read_csv(f'{word_path}/all_scripts_normalization.csv').set_index('title')
df
# Out:
#                             level_1   level_2   level_3   level_4   level_5  \
# title
# 13TH                       0.638573  1.000000  0.854711  0.798213  0.547864
# About.Time                 0.406597  0.258256  0.253148  0.281203  0.298882
# Anne.with.an.E             0.068061  0.157898  0.216540  0.565131  0.211236
# Arthur.Christmas           0.470796  0.285005  0.367086  0.596146  0.548032
# Baby.Driver                0.390550  0.225104  0.257936  0.300406  0.227602
# ...                             ...       ...       ...       ...       ...
# There.Will.Be.Blood        0.174525  0.078743  0.070710  0.051295  0.060416
# Three.Identical.Strangers  0.563857  0.386476  0.356988  0.247668  0.276383
# Virunga                    0.379505  0.412635  0.163970  0.174190  0.123036
# What.the.Health            0.786912  0.947490  1.000000  1.000000  1.000000
# Zodiac                     0.365929  0.288729  0.283620  0.445057  0.354868
#
# ...

# %% [markdown]
# ## level 별 가중치 계산

# %%
df_result = df.copy()
level_1 = df_result['level_1'] * 1
level_2 = df_result['level_2'] * 2
level_3 = df_result['level_3'] * 3
level_4 = df_result['level_4'] * 4
level_5 = df_result['level_5'] * 5
level_6 = df_result['level_6'] * 6

df_result['level_score'] = level_1 + level_2 + level_3 + level_4 + level_5 + level_6
df_result
# Out:
#                             level_1   level_2   level_3   level_4   level_5  \
# title
# 13TH                       0.638573  1.000000  0.854711  0.798213  0.547864
# About.Time                 0.406597  0.258256  0.253148  0.281203  0.298882
# Anne.with.an.E             0.068061  0.157898  0.216540  0.565131  0.211236
# Arthur.Christmas           0.470796  0.285005  0.367086  0.596146  0.548032
# Baby.Driver                0.390550  0.225104  0.257936  0.300406  0.227602
# ...                             ...       ...       ...       ...       ...
# There.Will.Be.Blood        0.174525  0.078743  0.070710  0.051295  0.060416
# Three.Identical.Strangers  0.563857  0.386476  0.356988  0.247668  0.276383
# Virunga                    0.379505  0.412635  0.163970  0.174190  0.123036
# What.the.Health            0.786912  0.947490  1.000000  1.000000  1.000000
# Zodiac                     0.365929  0.288729  0.283620  0.445057  0.354868
#
# ...

# %% [markdown]
# ## WPS Score 계산

# %%
df_result['wps_score'] = df_result['WPS_mean_nlln'] * 3
df_result
# Out:
#                             level_1   level_2   level_3   level_4   level_5  \
# title
# 13TH                       0.638573  1.000000  0.854711  0.798213  0.547864
# About.Time                 0.406597  0.258256  0.253148  0.281203  0.298882
# Anne.with.an.E             0.068061  0.157898  0.216540  0.565131  0.211236
# Arthur.Christmas           0.470796  0.285005  0.367086  0.596146  0.548032
# Baby.Driver                0.390550  0.225104  0.257936  0.300406  0.227602
# ...                             ...       ...       ...       ...       ...
# There.Will.Be.Blood        0.174525  0.078743  0.070710  0.051295  0.060416
# Three.Identical.Strangers  0.563857  0.386476  0.356988  0.247668  0.276383
# Virunga                    0.379505  0.412635  0.163970  0.174190  0.123036
# What.the.Health            0.786912  0.947490  1.000000  1.000000  1.000000
# Zodiac                     0.365929  0.288729  0.283620  0.445057  0.354868
#
# ...

# %% [markdown]
# ## Final Score 계산

# %%
df_result['final_score'] = df_result['level_score'] + df_result['wps_score']
df_result
# Out:
#                             level_1   level_2   level_3   level_4   level_5  \
# title
# 13TH                       0.638573  1.000000  0.854711  0.798213  0.547864
# About.Time                 0.406597  0.258256  0.253148  0.281203  0.298882
# Anne.with.an.E             0.068061  0.157898  0.216540  0.565131  0.211236
# Arthur.Christmas           0.470796  0.285005  0.367086  0.596146  0.548032
# Baby.Driver                0.390550  0.225104  0.257936  0.300406  0.227602
# ...                             ...       ...       ...       ...       ...
# There.Will.Be.Blood        0.174525  0.078743  0.070710  0.051295  0.060416
# Three.Identical.Strangers  0.563857  0.386476  0.356988  0.247668  0.276383
# Virunga                    0.379505  0.412635  0.163970  0.174190  0.123036
# What.the.Health            0.786912  0.947490  1.000000  1.000000  1.000000
# Zodiac                     0.365929  0.288729  0.283620  0.445057  0.354868
#
# ...

# %% [markdown]
# ## csv 파일로 변환

# %%
df_result.to_csv(f'{word_path}/all_scripts_final_score.csv')
