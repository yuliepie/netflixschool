# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import numpy as np
import warnings
import requests
warnings.filterwarnings('ignore')

# plt.rcParams['font.family'] = 'AppleGothic'
# plt.rcParams['font.family'] = 'NanumGothic'

# %% [markdown]
# ## path 설정

# %%
path = '../..'
script_path = f'{path}/script'
word_path = f'{path}/words/final_datasets'

# %% [markdown]
# ## 결과 데이터프레임 생성

# %%
if os.path.exists(f'{script_path}/csv_files/all_scripts_word_level_counts.csv'):
    df_result = pd.read_csv(f'{script_path}/csv_files/all_scripts_word_level_counts.csv', index_col='title')
else:
    df_result = pd.DataFrame(columns=['title', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'level_6']).set_index('title')

df_result
# Out:
#                                               level_1  level_2  level_3  \
# title
# 13TH                                             3732      833      606
# About.Time                                       3220      317      257
# Arthur.Christmas                                 2293      228      240
# Baby.Driver                                      2849      246      351
# Bad.Boys                                         3707      344      392
# Bee.Movie                                        2940      421      379
# Ben.Platt.Live.from.Radio.City.Music.Hall        1157       76       78
# Bo.Burnham_.Inside                                983      117       70
# Bo.Burnham_.Make.Happy                           1165      119      137
# Chasing.Coral                                    2526      300      439
# Constantine                                      1809      202      217
# Dave.Chappelle_.Sticks.&.Stones                  2203      217      247
# Dave.Chappelle_.Sticks._.Stones                  2357      217      251
# David.Attenborough_.A.Life.on.Our.Planet         2035      413      384
# Disclosure                                       3793      425      520
# Dolittle                                         2120      279      240
# Dracula.Untold                                   1162      146      156
# Enola.Holmes                                     2616      342      270
# FYRE_.The.Greatest.Party.That.Never.Happened     4679      576      431
# Heroin(e)                                        1318      162      117
# How.to.Be.Single                                 3698      285      267
# In.Time                                          2094      194      116
# Inception                                        3819      321      215
# Inside.Job                                       3689     1192      801
# Interstellar                                     4158      572      524
# It_s.Complicated                                 3606      243      219
# Jumanji_.Welcome.to.the.Jungle                   3014      283      330
# Kill.Bill_.Vol..1                                1011      127      161
# Kiss.the.Ground                                  2571      557      519
# Klaus                                            2433      168      155
# Knock.Down.The.House                             2393      386      203
# Kung.Fu.Panda                                    1514      176      140
# Kung.Fu.Panda.2                                  1556      176      137
# Kung.Fu.Panda.3                                  2052      177      148
# Madagascar_.Escape.2.Africa                      2610      268      248
# Matilda                                          2205      210      202
# Monty.Python.and.the.Holy.Grail                  1816      279      310
# Morning.Glory                                    3917      422      352
# Notting.Hill                                     3338      321      276
# Passengers                                       2100      204      201
# Penguins.of.Madagascar_.The.Movie                2030      329      384
# Prisoners                                        3027      200      216
# Seaspiracy                                       4078      670      776
# Second.Act                                       3333      336      248
# The.Accountant                                   2751      428      370
# The.Boy.in.the.Striped.Pajamas                   1243      137       89
# The.Dark.Knight                                  4162      490      430
# The.Departed                                     4243      428      653
# The.Family.Man                                   3386      285      216
# The.Intern                                       4910      382      306
# The.Judge                                        3459      396      299
# The.Revenant                                     1778      186      164
# The.Social.Dilemma                               3870      600      489
# The.Truman.Show                                  2261      164      146
# There.Will.Be.Blood                              2898      230      258
# Three.Identical.Strangers                        3116      283      247
# Virunga                                          1580      243      158
# What.the.Health                                  5126      824      870
# Zodiac                                           5421      529      421
#
#                                               level_4  level_5  level_6
# title
# 13TH                                              115       44       44
# About.Time                                         47       27       14
# Arthur.Christmas                                  106       49       39
# Baby.Driver                                        77       21       43
# Bad.Boys                                           94       57       40
# Bee.Movie                                          76       30       62
# Ben.Platt.Live.from.Radio.City.Music.Hall          12        7       14
# Bo.Burnham_.Inside                                 11        5        8
# Bo.Burnham_.Make.Happy                             22       21       20
# Chasing.Coral                                      54       21       25
# Constantine                                        34       22       17
# Dave.Chappelle_.Sticks.&.Stones                    40       33       32
# Dave.Chappelle_.Sticks._.Stones                    35       29       32
# David.Attenborough_.A.Life.on.Our.Planet           59       15       22
# Disclosure                                         90       53       91
# Dolittle                                           65       24       29
# Dracula.Untold                                     39        7        2
# Enola.Holmes                                       62       25       22
# FYRE_.The.Greatest.Party.That.Never.Happened       78       36       56
# Heroin(e)                                          32        7       10
# How.to.Be.Single                                   64       57       28
# In.Time                                            23        1        7
# Inception                                         118       26       20
# Inside.Job                                         72       27       44
# Interstellar                                      107       43       79
# It_s.Complicated                                   44       18       18
# Jumanji_.Welcome.to.the.Jungle                     73       31       40
# Kill.Bill_.Vol..1                                  31       34       18
# Kiss.the.Ground                                    92       36       63
# Klaus                                              72       24       26
# Knock.Down.The.House                               41       12       19
# Kung.Fu.Panda                                      61        4       20
# Kung.Fu.Panda.2                                    77       17       21
# Kung.Fu.Panda.3                                    91       26       21
# Madagascar_.Escape.2.Africa                        62       23       35
# Matilda                                            43       34       43
# Monty.Python.and.the.Holy.Grail                    96       21       58
# Morning.Glory                                      80       47       75
# Notting.Hill                                       60       45       32
# Passengers                                         26       16       42
# Penguins.of.Madagascar_.The.Movie                  91       32       47
# Prisoners                                          41       12       14
# Seaspiracy                                         98       46       45
# Second.Act                                         52       34       30
# The.Accountant                                     68       28       38
# The.Boy.in.the.Striped.Pajamas                     25        2        7
# The.Dark.Knight                                    70       57       44
# The.Departed                                      126       37       47
# The.Family.Man                                     59       18       17
# The.Intern                                         55       34       46
# The.Judge                                         142       26       35
# The.Revenant                                       84       19        7
# The.Social.Dilemma                                 64       48       35
# The.Truman.Show                                    74       10        8
# There.Will.Be.Blood                                44       12       38
# Three.Identical.Strangers                          37       38       21
# Virunga                                            49       11       16
# What.the.Health                                   124      107       93
# Zodiac                                            137       49       64

# %%
pd.set_option('display.max_rows', 30)

# %% [markdown]
# ## 자막(단어) 파일 불러오기

# %% [markdown]
# ### 경로 설정

# %%
# 다큐멘터리(0), 드라마(1), 영화(2) 선택
category = 1
if category == 0:
    script_path_cat = script_path + '/Documentary'
elif category == 1:
    script_path_cat = script_path + '/Drama'
else:
    script_path_cat = script_path + '/Movie'

_list = os.listdir(script_path_cat)

file_list = []
for file in _list:
    if file.startswith('.'): continue
    file_list.append(file)

file_list = sorted(file_list)
print(f'작품개수: {len(file_list)}')
count = 0
for index, title in enumerate(file_list):
    print(f'[{index}: {title}]', end=', ')
    count += 1
    if count%5 == 0:
        print()
# Out:
# 작품개수: 22
# [0: Anne.with.an.E], [1: Ben.&.Holly's.Little.Kingdom], [2: Better.Call.Saul], [3: Black.Mirror], [4: Breaking.Bad],
# [5: Chico.Bon.Bon_.Monkey.with.a.Tool.Belt], [6: Disenchantment], [7: Friends], [8: Gabbys.Dollhouse], [9: How.to.Get.Away.With.Murder],
# [10: MINDHUNTER], [11: Narcos], [12: PAW.Patrol], [13: Peaky.Blinders], [14: Peppa.Pig],
# [15: Rick.and.Morty], [16: Sherlock], [17: Splash.and.Bubbles], [18: Stranger.Things], [19: The.Good.Doctor],
# [20: The.Worst.Witch], [21: Treehouse.Detectives_2],

# %% [markdown]
# ### 작품 선택

# %%
# 바로 위 코드에서 file_list를 참고하여 작품 선택
title = file_list[3]
# if (df_result.index == title).any(): print(f'{title} is already exists')
file_name = 'unique_words_' + title + '.WEBRip.Netflix.en[cc]'
print(f'{script_path_cat}/{title}/{file_name}')
# Out:
# ../../script/Drama/Black.Mirror/unique_words_Black.Mirror.WEBRip.Netflix.en[cc]

# %% [markdown]
# ## unique_words_작품.csv to DataFrame

# %%
pd.set_option('display.max_rows', 30)

counts_df = pd.read_csv(f'{script_path_cat}/{title}/{file_name}.csv', index_col='word')
display(counts_df.info(), counts_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2995 entries, just to zoom
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   counts  2995 non-null   int64
# dtypes: int64(1)
# memory usage: 46.8+ KB
# None
#             counts
# word
# just           241
# know           167
# so             117
# can            103
# now             97
# ...            ...
# hiya             1
# hive             1
# historical       1
# higher           1
# zoom             1
#
# [2995 rows x 1 columns]

# %% [markdown]
# ## 변형형을 원형으로 변환 후 다시 세기

# %%
# 단어 리스트 불러오기
pd.options.display.float_format = '{:.0f}'.format

word_db_df = pd.read_csv(f'{word_path}/words_df_word_level_final.csv')
word_db_df
word_db_df.set_index('Word', inplace=True)

#변형어 리스트 불러오기
existing_lemmas = pd.read_csv(f'{word_path}/existing_lemmas_final.csv', index_col='Word')
lemmas_dict = {}
for index, row in existing_lemmas.iterrows():
    lemmas = row["Lemmas"].split(';')
    for lemma in lemmas:
        lemmas_dict[lemma] = str(index)

def convertToHeadForm(word):
    word = str(word)
    head = lemmas_dict.get(word)
    # If a lemma word, change to head word in word list
    if head:
        return head
    if word in word_db_df.index:
        return word
    else:
        # Check if adverb
        if word.endswith('ly'):
            if word[:-2] in word_db_df.index:
                print(word[:-2])
                return word[:-2]
            if word.endswith('ily'):
                if (word[:-3] + 'y') in word_db_df.index:
                    print(word[:-3] + 'y')
                    return word[:-3] + 'y'
            if word.endswith('ally'):
                if (word[:-4]) in word_db_df.index:
                    print(word[:-4])
                    return word[:-4]
            if (word[:-2] + 'e') in word_db_df.index:
                print(word[:-2] + 'e')
                return word[:-2] + 'e'
        return word

counts_df.index = counts_df.index.map(convertToHeadForm)
counts_df

counts_df_headed = counts_df.groupby(counts_df.index).sum()
counts_df_headed.sort_values('counts', ascending=False, inplace=True)

counts_df_headed
# counts_df_headed.to_csv('test-about-time.csv')
# Out:
# pal
#          counts
# word
# just        241
# can         214
# know        189
# go          172
# get         119
# ...         ...
# horizon       1
# hooker        1
# hook          1
# hoo           1
# zoom          1
#
# [2348 rows x 1 columns]

# %% [markdown]
# ## word_level 컬럼 추가

# %%
counts_df_headed_joined = counts_df_headed.join(word_db_df[['word_level']])

counts_df_headed_joined
# Out:
#          counts  word_level
# word
# just        241           1
# can         214           1
# know        189           1
# go          172           1
# get         119           1
# ...         ...         ...
# horizon       1           3
# hooker        1           5
# hook          1           3
# hoo           1         NaN
# zoom          1           3
#
# [2348 rows x 2 columns]

# %% [markdown]
# ### level NaN 중 짧은단어 제거

# %%
# counts_df_headed_joined.drop('gon', inplace=True)

counts_df_headed_joined = counts_df_headed_joined[~((counts_df_headed_joined.index.str.len() < 4) & (counts_df_headed_joined['word_level'].isnull()))]

# counts_df_headed_joined.drop(counts_df_headed_joined[(counts_df_headed_joined.index.str.len() < 3) & (counts_df_headed_joined['word_level'].isnull())].index, inplace=True)

counts_df_headed_joined
# Out:
#           counts  word_level
# word
# just         241           1
# can          214           1
# know         189           1
# go           172           1
# get          119           1
# ...          ...         ...
# horrible       1           2
# horizon        1           3
# hooker         1           5
# hook           1           3
# zoom           1           3
#
# [2327 rows x 2 columns]

# %% [markdown]
# ## Group by word_level

# %% [markdown]
# ## 불용어 제거

# %% [markdown]
# 불용어를 제거하기 위해 2가지 리소스를 사용한다
# - all_words.json는 사용하려고 했으나 불용어가 너무많이 포함되어 빼버림.
# - nltk synsets
# - 외부 API

# %%
# all_english_words = pd.read_csv("../../words/final_datasets/all_english_words.csv")

# all_english_words

# english_dict = {}
# for word in all_english_words['Word']:
#   english_dict[word] = 1

# english_dict

# %%
pd.set_option('display.max_rows', 30)

counts_copy = counts_df_headed_joined.copy(deep=True)

counts_copy
# Out:
#           counts  word_level
# word
# just         241           1
# can          214           1
# know         189           1
# go           172           1
# get          119           1
# ...          ...         ...
# horrible       1           2
# horizon        1           3
# hooker         1           5
# hook           1           3
# zoom           1           3
#
# [2327 rows x 2 columns]

# %%
nn_level = counts_copy[counts_copy['word_level'].isnull()]

pd.set_option('display.max_rows', None)
nn_level
# Out:
#                  counts  word_level
# word
# monogamist            5         NaN
# paedophile            4         NaN
# fianc                 4         NaN
# yous                  4         NaN
# titties               3         NaN
# grainless             3         NaN
# obit                  3         NaN
# haired                2         NaN
# showreel              2         NaN
# waldo                 2         NaN
# unsimulated           2         NaN
# botherguts            2         NaN
# wanna                 2         NaN
# innit                 2         NaN
# monologue             2         NaN
# patronise             2         NaN
# dopple                2         NaN
# clockage              2         NaN
# faker                 2         NaN
# wack                  1         NaN
# yadder                1         NaN
# popstars              1         NaN
# weirded               1         NaN
# ppos                  1         NaN
# realer                1         NaN
# recognised            1         NaN
# recognise             1         NaN
# snooty                1         NaN
# toon                  1         NaN
# snotted               1         NaN
# tantalising           1         NaN
# sympathise            1         NaN
# tanking               1         NaN
# tasers                1         NaN
# threwerchep           1         NaN
# uploads               1         NaN
# unlikeable            1         NaN
# usuals                1         NaN
# vandalised            1         NaN
# vapidity              1         NaN
# tres                  1         NaN
# schoolkid             1         NaN
# shirtless             1         NaN
# schoolkids            1         NaN
# underdone             1         NaN
# codeword              1         NaN
# conversate            1         NaN
# envoke                1         NaN
# energising            1         NaN
# erotica               1         NaN
# earnt                 1         NaN
# autocue               1         NaN
# achingly              1         NaN
# adventurousness       1         NaN
# anaesthetic           1         NaN
# chroma                1         NaN
# bibble                1         NaN
# bellends              1         NaN
# batshit               1         NaN
# bish                  1         NaN
# mesmerised            1         NaN
# naturism              1         NaN
# lorcan                1         NaN
# looker                1         NaN
# maam                  1         NaN
# meagre                1         NaN
# marakeechian          1         NaN
# manikin               1         NaN
# perv                  1         NaN
# pervs                 1         NaN
# parenting             1         NaN
# pillock               1         NaN
# pickings              1         NaN
# phoney                1         NaN
# ooops                 1         NaN
# oooh                  1         NaN
# nutcase               1         NaN
# leaderballs           1         NaN
# grandad               1         NaN
# face-book             1         NaN
# finessing             1         NaN
# iphones               1         NaN
# intercut              1         NaN
# islamist              1         NaN
# lardy                 1         NaN
# heroic                1         NaN
# heartbreaker          1         NaN
# headspace             1         NaN
# hiya                  1         NaN
# hominem               1         NaN
# husting               1         NaN

# %%
# for null words, if null word in english_dict, put level as 6.

# for index, row in nn_level.iterrows():
#   if english_dict.get(str(index)) == 1:
#     print(index)
#     counts_copy.loc[index, 'word_level'] = 6

# nn_level = counts_copy[counts_copy['word_level'].isnull()]
# nn_level

# %%
from nltk.corpus import wordnet, words

included = []

for index in nn_level.index:
  if len(wordnet.synsets(str(index))) > 0:
    included.append(str(index))
    counts_copy.loc[index, 'word_level'] = 6

print(included)

nn_level = counts_copy[counts_copy['word_level'].isnull()]
nn_level
# Out:
# ['monogamist', 'paedophile', 'titties', 'obit', 'haired', 'monologue', 'patronise', 'faker', 'realer', 'recognised', 'recognise', 'snooty', 'toon', 'tantalising', 'sympathise', 'tanking', 'uploads', 'unlikeable', 'vandalised', 'vapidity', 'underdone', 'energising', 'erotica', 'autocue', 'adventurousness', 'anaesthetic', 'chroma', 'mesmerised', 'naturism', 'looker', 'meagre', 'manikin', 'parenting', 'pillock', 'pickings', 'phoney', 'nutcase', 'grandad', 'finessing', 'islamist', 'heroic', 'heartbreaker', 'headspace']
#               counts  word_level
# word
# fianc              4         NaN
# yous               4         NaN
# grainless          3         NaN
# showreel           2         NaN
# waldo              2         NaN
# unsimulated        2         NaN
# botherguts         2         NaN
# wanna              2         NaN
# innit              2         NaN
# dopple             2         NaN
# clockage           2         NaN
# wack               1         NaN
# yadder             1         NaN
# popstars           1         NaN
# weirded            1         NaN
# ppos               1         NaN
# snotted            1         NaN
# tasers             1         NaN
# threwerchep        1         NaN
# usuals             1         NaN
# tres               1         NaN
# schoolkid          1         NaN
# shirtless          1         NaN
# schoolkids         1         NaN
# codeword           1         NaN
# conversate         1         NaN
# envoke             1         NaN
# earnt              1         NaN
# achingly           1         NaN
# bibble             1         NaN
# bellends           1         NaN
# batshit            1         NaN
# bish               1         NaN
# lorcan             1         NaN
# maam               1         NaN
# marakeechian       1         NaN
# perv               1         NaN
# pervs              1         NaN
# ooops              1         NaN
# oooh               1         NaN
# leaderballs        1         NaN
# face-book          1         NaN
# iphones            1         NaN
# intercut           1         NaN
# lardy              1         NaN
# hiya               1         NaN
# hominem            1         NaN
# husting            1         NaN

# %%
def check_word_type_api(word):
  headers = {'User-Agent':'Chrome/66.0.3359.181'}

  keyword = str(word)
  url = 'https://wordtype.org/api/senses?term=' + keyword
  res = requests.get(url, headers=headers)
  results = res.json()
  try:
    if len(results) == 0:
      return False
    # check if any word with correct pos & definition
    for item in results:
      if item['pos'] in ['interjection', 'abbreviation']:
        return False
    for item in results:
      if item['pos'] in ['noun', 'verb', 'adjective', 'adverb']:
        for sense in item['senses']:
          if sense['definition'] != "" and sense['definition'] != '<missing sense definition>':
            return True
    if word.endswith('s'):
      return check_word_type_api(word[:-1])
    else:
      return False
  except Exception as e:
    print("error:", e)

# %%
a = check_word_type_api('froggies')
a
# Out:
# False

# %%
for index, row in nn_level.iterrows():
  if check_word_type_api(str(index)) == True:
    print(index)
    counts_copy.loc[index, 'word_level'] = 6

nn_level = counts_copy[counts_copy['word_level'].isnull()]
nn_level
# Out:
# showreel
# waldo
# unsimulated
# wack
# tasers
# schoolkid
# shirtless
# schoolkids
# codeword
# conversate
# achingly
# bibble
# batshit
# bish
# perv
# pervs
# intercut
# lardy
# husting
#               counts  word_level
# word
# fianc              4         NaN
# yous               4         NaN
# grainless          3         NaN
# botherguts         2         NaN
# wanna              2         NaN
# innit              2         NaN
# dopple             2         NaN
# clockage           2         NaN
# yadder             1         NaN
# popstars           1         NaN
# weirded            1         NaN
# ppos               1         NaN
# snotted            1         NaN
# threwerchep        1         NaN
# usuals             1         NaN
# tres               1         NaN
# envoke             1         NaN
# earnt              1         NaN
# bellends           1         NaN
# lorcan             1         NaN
# maam               1         NaN
# marakeechian       1         NaN
# ooops              1         NaN
# oooh               1         NaN
# leaderballs        1         NaN
# face-book          1         NaN
# iphones            1         NaN
# hiya               1         NaN
# hominem            1         NaN

# %%
counts_copy_final = counts_copy.drop(nn_level.index)
# counts_copy_final.to_csv("../../script/csv_files/unique_words_with_all_levels.csv")

counts_copy_final[counts_copy_final['word_level'].isnull()]
# Out:
#                  counts  word_level
# word
# just                241           1
# can                 214           1
# know                189           1
# go                  172           1
# get                 119           1
# so                  117           1
# come                115           1
# say                 107           1
# look                103           1
# see                  98           1
# now                  97           1
# here                 93           1
# think                93           1
# there                90           1
# want                 88           1
# fuck                 69           3
# good                 68           1
# do                   66           1
# mean                 65           1
# thing                65           1
# how                  60           1
# why                  60           1
# back                 59           1
# really               59           1
# right                58           1
# will                 56           1
# would                56           1
# make                 55           1
# time                 50           1
# then                 48           1
# when                 48           1
# take                 47           1
# like                 46           1
# more                 45           1
# need                 44           1
# let                  43           1
# people               43           1
# talk                 43           1
# where                42           1
# thank                42           1
# happen               39           1
# work                 39           1
# man                  35           1
# tell                 34           1
# head                 34           1
# watch                34           1
# gravy                 1           4
# graphic               1           3
# grandad               1           6
# grade                 1           2
# goon                  1           6
# goodnight             1           5
# goodness              1           3
# goddamn               1           5
# glorify               1           4
# globe                 1           3
# glide                 1           3
# girlfriend            1           1
# gesture               1           3
# formulate             1           3
# formally              1           3
# hall                  1           1
# fictional             1           3
# festive               1           4
# feral                 1           5
# female                1           1
# feed                  1           1
# feeble                1           4
# fear                  1           1
# favour                1           3
# father                1           1
# fate                  1           3
# fatal                 1           3
# fat                   1           1
# fast                  1           1
# fascinate             1           3
# fart                  1           5
# farewell              1           3
# fang                  1           5
# familiar              1           2
# false                 1           1
# faith                 1           2
# extraordinary         1           2
# fez                   1           6
# field                 1           1
# formal                1           1
# figurehead            1           6
# fork                  1           1
# forest                1           1
# force                 1           2
# fold                  1           2
# foam                  1           3
# floor                 1           1
# float                 1           2
# fling                 1           3
# flesh                 1           3
# flatter               1           3
# flat                  1           1
# flash                 1           2
# fish                  1           1
# fingertip             1           4
# finessing             1           6
# financial             1           2
# finale                1           3
# filth                 1           4
# filter                1           3
# fill                  1           1
# file                  1           2
# halfway               1           3
# handle                1           2
# law                   1           1
# invective             1           6
# intervene             1           3
# interrogation         1           3
# intercut              1           6
# intercept             1           3
# interactive           1           3
# intelligent           1           1
# insurrection          1           4
# insurance             1           2
# instruct              1           3
# instinctively         1           4
# instead               1           1
# instantly             1           3
# install               1           2
# innocence             1           3
# injunction            1           3
# ingrain               1           5
# ingest                1           5
# infrastructure        1           3
# informative           1           3
# information           1           1
# irony                 1           3
# inflate               1           3
# islamist              1           6
# lardy                 1           6
# language              1           1
# lamppost              1           6
# lamp                  1           1
# lady                  1           1
# ladder                1           3
# lack                  1           2
# labour                1           3
# label                 1           2
# knockout              1           4
# knack                 1           4
# kingdom               1           3
# king                  1           1
# key                   1           1
# keen                  1           3
# justice               1           2
# jury                  1           3
# judge                 1           2
# jail                  1           3
# isolate               1           3
# info                  1           3
# industry              1           1
# handsome              1           3
# hobby                 1           1
# hive                  1           2
# historical            1           2
# hideous               1           4
# heroic                1           6
# hereby                1           4
# hence                 1           3
# helpless              1           3
# helmet                1           3
# heartfelt             1           5
# heartbreaker          1           6
# heartbeat             1           4
# healthy               1           1
# health                1           1
# headspace             1           6
# headphone             1           4
# haunt                 1           3
# harsh                 1           3
# harrow                1           4
# harpoon               1           4
# harm                  1           2
# harden                1           3
# hole                  1           1
# indeed                1           2
# inclusion             1           3
# include               1           1
# incident              1           2
# impressive            1           2
# impress               1           2
# importance            1           2
# illness               1           1
# idol                  1           3
# icebreaker            1           6
# i                     1           1
# husting               1           6
# husband               1           1
# hungry                1           1
# humour                1           3
# humiliate             1           3
# host                  1           2
# horrible              1           2
# horizon               1           3
# hooker                1           5
# hook                  1           3
# zoom                  1           3

# %%
# test['words_words'] = test['word'].apply(lambda x: True if x in words.words() else False)
# test

# %%
result = counts_df_headed_joined.groupby('word_level').sum('counts').transpose()
result['title'] = title
result = result.set_index('title')
result = result.rename(columns={1: 'level_1', 2: 'level_2', 3: 'level_3', 4: 'level_4', 5: 'level_5', 6: 'level_6'})
result
# Out:
# word_level  level_1  level_2  level_3  level_4  level_5  level_6
# title
# About.Time     3220      317      257       47       27       14

# %% [markdown]
# ## df_result에 추가

# %%
df_result = pd.concat([df_result, result])
df_result
# Out:
#                                               level_1  level_2  level_3  \
# title
# 13TH                                             3732      833      606
# About.Time                                       3220      317      257
# Arthur.Christmas                                 2293      228      240
# Baby.Driver                                      2849      246      351
# Bad.Boys                                         3707      344      392
# Bee.Movie                                        2940      421      379
# Ben.Platt.Live.from.Radio.City.Music.Hall        1157       76       78
# Bo.Burnham_.Inside                                983      117       70
# Bo.Burnham_.Make.Happy                           1165      119      137
# Chasing.Coral                                    2526      300      439
# Constantine                                      1809      202      217
# Dave.Chappelle_.Sticks.&.Stones                  2203      217      247
# Dave.Chappelle_.Sticks._.Stones                  2357      217      251
# David.Attenborough_.A.Life.on.Our.Planet         2035      413      384
# Disclosure                                       3793      425      520
# Dolittle                                         2120      279      240
# Dracula.Untold                                   1162      146      156
# Enola.Holmes                                     2616      342      270
# FYRE_.The.Greatest.Party.That.Never.Happened     4679      576      431
# Heroin(e)                                        1318      162      117
# How.to.Be.Single                                 3698      285      267
# In.Time                                          2094      194      116
# Inception                                        3819      321      215
# Inside.Job                                       3689     1192      801
# Interstellar                                     4158      572      524
# It_s.Complicated                                 3606      243      219
# Jumanji_.Welcome.to.the.Jungle                   3014      283      330
# Kill.Bill_.Vol..1                                1011      127      161
# Kiss.the.Ground                                  2571      557      519
# Klaus                                            2433      168      155
# Knock.Down.The.House                             2393      386      203
# Kung.Fu.Panda                                    1514      176      140
# Kung.Fu.Panda.2                                  1556      176      137
# Kung.Fu.Panda.3                                  2052      177      148
# Madagascar_.Escape.2.Africa                      2610      268      248
# Matilda                                          2205      210      202
# Monty.Python.and.the.Holy.Grail                  1816      279      310
# Morning.Glory                                    3917      422      352
# Notting.Hill                                     3338      321      276
# Passengers                                       2100      204      201
# Penguins.of.Madagascar_.The.Movie                2030      329      384
# Prisoners                                        3027      200      216
# Seaspiracy                                       4078      670      776
# Second.Act                                       3333      336      248
# The.Accountant                                   2751      428      370
# The.Boy.in.the.Striped.Pajamas                   1243      137       89
# The.Dark.Knight                                  4162      490      430
# The.Departed                                     4243      428      653
# The.Family.Man                                   3386      285      216
# The.Intern                                       4910      382      306
# The.Judge                                        3459      396      299
# The.Revenant                                     1778      186      164
# The.Social.Dilemma                               3870      600      489
# The.Truman.Show                                  2261      164      146
# There.Will.Be.Blood                              2898      230      258
# Three.Identical.Strangers                        3116      283      247
# Virunga                                          1580      243      158
# What.the.Health                                  5126      824      870
# Zodiac                                           5421      529      421
#
#                                               level_4  level_5  level_6
# title
# 13TH                                              115       44       44
# About.Time                                         47       27       14
# Arthur.Christmas                                  106       49       39
# Baby.Driver                                        77       21       43
# Bad.Boys                                           94       57       40
# Bee.Movie                                          76       30       62
# Ben.Platt.Live.from.Radio.City.Music.Hall          12        7       14
# Bo.Burnham_.Inside                                 11        5        8
# Bo.Burnham_.Make.Happy                             22       21       20
# Chasing.Coral                                      54       21       25
# Constantine                                        34       22       17
# Dave.Chappelle_.Sticks.&.Stones                    40       33       32
# Dave.Chappelle_.Sticks._.Stones                    35       29       32
# David.Attenborough_.A.Life.on.Our.Planet           59       15       22
# Disclosure                                         90       53       91
# Dolittle                                           65       24       29
# Dracula.Untold                                     39        7        2
# Enola.Holmes                                       62       25       22
# FYRE_.The.Greatest.Party.That.Never.Happened       78       36       56
# Heroin(e)                                          32        7       10
# How.to.Be.Single                                   64       57       28
# In.Time                                            23        1        7
# Inception                                         118       26       20
# Inside.Job                                         72       27       44
# Interstellar                                      107       43       79
# It_s.Complicated                                   44       18       18
# Jumanji_.Welcome.to.the.Jungle                     73       31       40
# Kill.Bill_.Vol..1                                  31       34       18
# Kiss.the.Ground                                    92       36       63
# Klaus                                              72       24       26
# Knock.Down.The.House                               41       12       19
# Kung.Fu.Panda                                      61        4       20
# Kung.Fu.Panda.2                                    77       17       21
# Kung.Fu.Panda.3                                    91       26       21
# Madagascar_.Escape.2.Africa                        62       23       35
# Matilda                                            43       34       43
# Monty.Python.and.the.Holy.Grail                    96       21       58
# Morning.Glory                                      80       47       75
# Notting.Hill                                       60       45       32
# Passengers                                         26       16       42
# Penguins.of.Madagascar_.The.Movie                  91       32       47
# Prisoners                                          41       12       14
# Seaspiracy                                         98       46       45
# Second.Act                                         52       34       30
# The.Accountant                                     68       28       38
# The.Boy.in.the.Striped.Pajamas                     25        2        7
# The.Dark.Knight                                    70       57       44
# The.Departed                                      126       37       47
# The.Family.Man                                     59       18       17
# The.Intern                                         55       34       46
# The.Judge                                         142       26       35
# The.Revenant                                       84       19        7
# The.Social.Dilemma                                 64       48       35
# The.Truman.Show                                    74       10        8
# There.Will.Be.Blood                                44       12       38
# Three.Identical.Strangers                          37       38       21
# Virunga                                            49       11       16
# What.the.Health                                   124      107       93
# Zodiac                                            137       49       64

# %% [markdown]
# # 위의 코드들 합쳐서 한 번에 모든 작품 돌리기

# %%
import os
import pandas as pd
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# import warnings
# warnings.filterwarnings('ignore')

# plt.rcParams['font.family'] = 'AppleGothic'
# plt.rcParams['font.family'] = 'NanumGothic'

path = '../..'
script_path = f'{path}/script'
word_path = f'{path}/words/final_datasets'

if os.path.exists(f'{script_path}/csv_files/all_scripts_word_level_counts.csv'):
    df_result = pd.read_csv(f'{script_path}/csv_files/all_scripts_word_level_counts.csv', index_col='title')
else:
    df_result = pd.DataFrame(columns=['title', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'level_6']).set_index('title')

display(df_result)

# 다큐멘터리(0), 드라마(1), 영화(2) 선택
category = 2
if category == 0:
    script_path_cat = script_path + '/Documentary'
elif category == 1:
    script_path_cat = script_path + '/Drama'
else:
    script_path_cat = script_path + '/Movie'

_list = os.listdir(script_path_cat)

file_list = []
for file in _list:
    if file.startswith('.'): continue
    file_list.append(file)

file_list = sorted(file_list)
print(f'작품개수: {len(file_list)}')
count = 0
for index, title in enumerate(file_list):
    print(f'[{index}: {title}]', end=', ')
    count += 1
    if count%5 == 0:
        print()
# Out:
# Empty DataFrame
# Columns: [level_1, level_2, level_3, level_4, level_5, level_6, running_time, WPS_mean, WPS_std, WPS_min, WPS_max, calculated, final_score]
# Index: []
# 작품개수: 41
# [0: About.Time], [1: Arthur.Christmas], [2: Baby.Driver], [3: Bad.Boys], [4: Bee.Movie],
# [5: Ben.Platt.Live.from.Radio.City.Music.Hall], [6: Constantine], [7: Dolittle], [8: Dracula.Untold], [9: Enola.Holmes],
# [10: How.to.Be.Single], [11: In.Time], [12: Inception], [13: Interstellar], [14: It_s.Complicated],
# [15: Jumanji_.Welcome.to.the.Jungle], [16: Kill.Bill_.Vol..1], [17: Klaus], [18: Kung.Fu.Panda], [19: Kung.Fu.Panda.2],
# [20: Kung.Fu.Panda.3], [21: Madagascar_.Escape.2.Africa], [22: Matilda], [23: Monty.Python.and.the.Holy.Grail], [24: Morning.Glory],
# [25: Notting.Hill], [26: Passengers], [27: Penguins.of.Madagascar_.The.Movie], [28: Prisoners], [29: Second.Act],
# [30: The.Accountant], [31: The.Boy.in.the.Striped.Pajamas], [32: The.Dark.Knight], [33: The.Departed], [34: The.Family.Man],
# [35: The.Intern], [36: The.Judge], [37: The.Revenant], [38: The.Truman.Show], [39: There.Will.Be.Blood],
# [40: Zodiac],

# %%
for i in range(len(file_list)):
    # 바로 위 코드에서 file_list를 참고하여 작품 선택
    title = file_list[i]
    if (df_result.index == title).any(): continue

    file_name = 'unique_words_' + title + '.WEBRip.Netflix.en[cc]'
    # print(f'{script_path_cat}/{title}/{file_name}')

    counts_df = pd.read_csv(f'{script_path_cat}/{title}/{file_name}.csv', index_col='word')

    # 단어 리스트 불러오기
    pd.options.display.float_format = '{:.0f}'.format

    word_db_df = pd.read_csv(f'{word_path}/words_df_word_level_final.csv')
    word_db_df.set_index('Word', inplace=True)

    #변형어 리스트 불러오기
    existing_lemmas = pd.read_csv(f'{word_path}/existing_lemmas_final.csv', index_col='Word')
    lemmas_dict = {}
    for index, row in existing_lemmas.iterrows():
        lemmas = row["Lemmas"].split(';')
        for lemma in lemmas:
            lemmas_dict[lemma] = str(index)

    def convertToHeadForm(word):
        word = str(word)
        head = lemmas_dict.get(word)
        # If a lemma word, change to head word in word list
        if head:
            return head
        if word in word_db_df.index:
            return word
        else:
            # Check if adverb
            if word.endswith('ly'):
                if word[:-2] in word_db_df.index:
                    # print(word[:-2])
                    return word[:-2]
                if word.endswith('ily'):
                    if (word[:-3] + 'y') in word_db_df.index:
                        # print(word[:-3] + 'y')
                        return word[:-3] + 'y'
                if word.endswith('ally'):
                    if (word[:-4]) in word_db_df.index:
                        # print(word[:-4])
                        return word[:-4]
                if (word[:-2] + 'e') in word_db_df.index:
                    # print(word[:-2] + 'e')
                    return word[:-2] + 'e'
            return word

    counts_df.index = counts_df.index.map(convertToHeadForm)

    counts_df_headed = counts_df.groupby(counts_df.index).sum()
    counts_df_headed.sort_values('counts', ascending=False, inplace=True)

    counts_df_headed_joined = counts_df_headed.join(word_db_df[['word_level']])

    result = counts_df_headed_joined.groupby('word_level').sum('counts').transpose()
    result['title'] = title
    result = result.set_index('title')
    result = result.rename(columns={1: 'level_1', 2: 'level_2', 3: 'level_3', 4: 'level_4', 5: 'level_5', 6: 'level_6'})

    df_result = pd.concat([df_result, result])

df_result
# Out:
#                                           level_1 level_2 level_3 level_4  \
# title
# About.Time                                    645     201     104      59
# Arthur.Christmas                              564     175     104      54
# Baby.Driver                                   604     165     122      46
# Bad.Boys                                      613     197     108      41
# Bee.Movie                                     654     230     156      70
# Ben.Platt.Live.from.Radio.City.Music.Hall     355      67      37      18
# Constantine                                   498     143      89      40
# Dolittle                                      586     217     109      55
# Dracula.Untold                                371     124      65      37
# Enola.Holmes                                  627     223     117      51
# How.to.Be.Single                              618     188     107      33
# In.Time                                       440     126      46      20
# Inception                                     567     181      89      21
# Interstellar                                  709     309     174      49
# It_s.Complicated                              617     160      96      37
# Jumanji_.Welcome.to.the.Jungle                578     166     106      45
# Kill.Bill_.Vol..1                             387     110      67      31
# Klaus                                         543     128      67      52
# Kung.Fu.Panda                                 415     119      65      24
# Kung.Fu.Panda.2                               439     124      46      37
# Kung.Fu.Panda.3                               444     100      65      30
# Madagascar_.Escape.2.Africa                   572     186      95      44
# Matilda                                       609     159      92      43
# Monty.Python.and.the.Holy.Grail               516     197      89      76
# Morning.Glory                                 722     252     154      70
# Notting.Hill                                  681     215     118      54
# Passengers                                    529     138      82      10
# Penguins.of.Madagascar_.The.Movie             574     186     145      55
# Prisoners                                     526     129      67      36
# Second.Act                                    699     210     129      34
# The.Accountant                                755     254     173      43
# The.Boy.in.the.Striped.Pajamas                383      92      34      18
# The.Dark.Knight                               747     311     177      68
# The.Departed                                  719     250     154      57
# The.Family.Man                                657     187     108      42
# The.Intern                                    736     216     130      37
# The.Judge                                     639     210     133      60
# The.Revenant                                  437      97      62      19
# The.Truman.Show                               517     115      75      27
# There.Will.Be.Blood                           525     150      76      27
# Zodiac                                        825     268     172      72
#
#                                           level_5 level_6 running_time  WPS  \
# title
# About.Time                                     24      13          NaN  NaN
# Arthur.Christmas                               40      28          NaN  NaN
# Baby.Driver                                    23      24          NaN  NaN
# Bad.Boys                                       35      29          NaN  NaN
# Bee.Movie                                      28      43          NaN  NaN
# Ben.Platt.Live.from.Radio.City.Music.Hall       9       7          NaN  NaN
# Constantine                                    18      16          NaN  NaN
# Dolittle                                       25      24          NaN  NaN
# Dracula.Untold                                  6       2          NaN  NaN
# Enola.Holmes                                   26      21          NaN  NaN
# How.to.Be.Single                               37      21          NaN  NaN
# In.Time                                         1       6          NaN  NaN
# Inception                                      13      13          NaN  NaN
# Interstellar                                   44      47          NaN  NaN
# It_s.Complicated                               24      15          NaN  NaN
# Jumanji_.Welcome.to.the.Jungle                 22      25          NaN  NaN
# Kill.Bill_.Vol..1                              17      14          NaN  NaN
# Klaus                                          24      21          NaN  NaN
# Kung.Fu.Panda                                   6      11          NaN  NaN
# Kung.Fu.Panda.2                                14      12          NaN  NaN
# Kung.Fu.Panda.3                                16      15          NaN  NaN
# Madagascar_.Escape.2.Africa                    25      29          NaN  NaN
# Matilda                                        28      39          NaN  NaN
# Monty.Python.and.the.Holy.Grail                15      30          NaN  NaN
# Morning.Glory                                  44      53          NaN  NaN
# Notting.Hill                                   34      21          NaN  NaN
# Passengers                                     19      19          NaN  NaN
# Penguins.of.Madagascar_.The.Movie              28      39          NaN  NaN
# Prisoners                                      10      12          NaN  NaN
# Second.Act                                     37      25          NaN  NaN
# The.Accountant                                 37      30          NaN  NaN
# The.Boy.in.the.Striped.Pajamas                  3       6          NaN  NaN
# The.Dark.Knight                                43      30          NaN  NaN
# The.Departed                                   38      32          NaN  NaN
# The.Family.Man                                 23      13          NaN  NaN
# The.Intern                                     40      31          NaN  NaN
# The.Judge                                      24      27          NaN  NaN
# The.Revenant                                   11       7          NaN  NaN
# The.Truman.Show                                14       7          NaN  NaN
# There.Will.Be.Blood                             8      18          NaN  NaN
# Zodiac                                         45      41          NaN  NaN
#
#                                           calculated final_score
# title
# About.Time                                       NaN         NaN
# Arthur.Christmas                                 NaN         NaN
# Baby.Driver                                      NaN         NaN
# Bad.Boys                                         NaN         NaN
# Bee.Movie                                        NaN         NaN
# Ben.Platt.Live.from.Radio.City.Music.Hall        NaN         NaN
# Constantine                                      NaN         NaN
# Dolittle                                         NaN         NaN
# Dracula.Untold                                   NaN         NaN
# Enola.Holmes                                     NaN         NaN
# How.to.Be.Single                                 NaN         NaN
# In.Time                                          NaN         NaN
# Inception                                        NaN         NaN
# Interstellar                                     NaN         NaN
# It_s.Complicated                                 NaN         NaN
# Jumanji_.Welcome.to.the.Jungle                   NaN         NaN
# Kill.Bill_.Vol..1                                NaN         NaN
# Klaus                                            NaN         NaN
# Kung.Fu.Panda                                    NaN         NaN
# Kung.Fu.Panda.2                                  NaN         NaN
# Kung.Fu.Panda.3                                  NaN         NaN
# Madagascar_.Escape.2.Africa                      NaN         NaN
# Matilda                                          NaN         NaN
# Monty.Python.and.the.Holy.Grail                  NaN         NaN
# Morning.Glory                                    NaN         NaN
# Notting.Hill                                     NaN         NaN
# Passengers                                       NaN         NaN
# Penguins.of.Madagascar_.The.Movie                NaN         NaN
# Prisoners                                        NaN         NaN
# Second.Act                                       NaN         NaN
# The.Accountant                                   NaN         NaN
# The.Boy.in.the.Striped.Pajamas                   NaN         NaN
# The.Dark.Knight                                  NaN         NaN
# The.Departed                                     NaN         NaN
# The.Family.Man                                   NaN         NaN
# The.Intern                                       NaN         NaN
# The.Judge                                        NaN         NaN
# The.Revenant                                     NaN         NaN
# The.Truman.Show                                  NaN         NaN
# There.Will.Be.Blood                              NaN         NaN
# Zodiac                                           NaN         NaN

# %% [markdown]
# ## csv파일로 변환

# %%
df_result = df_result.sort_index()
df_result.to_csv(f'{script_path}/csv_files/all_scripts_word_level_counts.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2700/3077918343.py in <module>
# ----> 1 df_result
#
# NameError: name 'df_result' is not defined
