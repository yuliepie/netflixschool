# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## path 설정

# %%
path = '../..'
csv_path = f'{path}/script/csv_files'

# %% [markdown]
# ## 파일 불러오기

# %%
file_name = 'all_scripts_final_score.csv'
df = pd.read_csv(f'{csv_path}/{file_name}', index_col='title')
df
# Out:
#                                                level_1   level_2   level_3  \
# title
# 13TH                                          0.609863  0.763039  0.611899
# About.Time                                    0.374061  0.174619  0.147663
# Arthur.Christmas                              0.325880  0.154821  0.198371
# Baby.Driver                                   0.330802  0.123976  0.254857
# Bad.Boys                                      0.473384  0.202440  0.285286
# Bee.Movie                                     0.474071  0.364282  0.370651
# Ben.Platt.Live.from.Radio.City.Music.Hall     0.098472  0.000000  0.009014
# Bo.Burnham_.Inside                            0.058552  0.054582  0.000000
# Bo.Burnham_.Make.Happy                        0.223802  0.112670  0.171000
# Chasing.Coral                                 0.438679  0.266234  0.502227
# Constantine                                   0.113922  0.074382  0.105655
# ...

# %% [markdown]
# ## 4사분면 그래프 그리기

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=df, x='level_score', y='wps_score', color='r')
plt.title('Netflix Contents English Difficulty Distribution', size=20, pad=20)

for i in range(df.shape[0]):
    plt.text(df.level_score[i], y=df.wps_score[i], s=df.index[i], alpha=0.7)

plt.axhline(y=2, color='k', linewidth=1, linestyle='-')
plt.text(x=10.2, y=4.1, s='WPS', weight='bold')
plt.axvline(x=10, color='k', linewidth=1, linestyle='-')
plt.text(x=20, y=1.9, s='word level', weight='bold')

plt.axis('off')

plt.show()

# Scatter Plot (Image by author)
