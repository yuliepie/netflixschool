# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'AppleGothic'
# plt.rcParams['font.family'] = 'NanumGothic'

# %%
pd.options.display.float_format = '{:.0f}'.format

word_db_df = pd.read_csv("../words/final_datasets/words_df_final_naver_proper_noun.csv")
word_db_df.set_index('Word', inplace=True)
word_db_df
# Out:
#             oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                     NN               0             0              NN    Y
# aback                 NN               0             0              NN    N
# abacus                NN               0             0              NN    N
# abalone               NN               0             0              NN    N
# abandon               B2            3000             0              NN    N
# ...                  ...             ...           ...             ...  ...
# zygomorphic           NN               0             0              NN    N
# zygosity              NN               0             0              NN    N
# zygote                NN               0             6         science    N
# zygotic               NN               0             0              NN    N
# émigré                NN               0             0              NN    N
#
# ...

# %%
lexile_grade = list(word_db_df['naver_priority'].unique())
lexile_grade
# Out:
# [2, 0, 1, -1, 3]

# %%
temp_word_db_df = word_db_df[word_db_df['lexile_grade'] == 1]
temp_word_db_df
# Out:
#          oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# activity           A1            3000             1         general    N
# addition           B1            3000             1         general    N
# alike              C1            5000             1         general    N
# analog             NN               0             1         science    N
# ant                NN               0             1         science    N
# ...               ...             ...           ...             ...  ...
# vote               B1            3000             1  social_studies    Y
# war                A2            3000             1  social_studies    N
# wave               A2            3000             1         science    Y
# wetland            NN               0             1         science    N
# wheat              B2            5000             1  social_studies    N
#
#          toefl tsl bsl ngsl_freq ngsl_sp_freq  naver_priority  lemmetized  \
# Word
# ...

# %%
oxford_level = ['A1','A2', 'B1', 'B2', 'C1']
lexile_grade = [1, 2, 3, 4, 5, 6, 9]
lexile_category = ['social_studies', 'general', 'science', 'math']
ngsl_freq = ['A1','A2', 'A3', 'A4', 'B1','B2','B3', 'C1', 'C2', 'C3', 'C4', 'C5']
ngsl_sp_freq = ['A1','A2', 'A3', 'A4', 'B1','B2','B3', 'C1', 'C2', 'C3']
naver_priority = [2, 1, 0]

# %%
df = pd.DataFrame()

# %%
for columns in oxford_level:
    df[f'oxford_level {columns}'] = 1

for columns in lexile_grade:
    df[f'lexile_grade {columns}'] = 1

for columns in lexile_category:
    df[f'lexile_category {columns}'] = 1

df[f'awsl'] = 1
df[f'toefl'] = 1
df[f'tsl'] = 1
df[f'bsl'] = 1

for columns in ngsl_freq:
    df[f'ngsl_freq {columns}'] = 1

for columns in ngsl_sp_freq:
    df[f'ngsl_sp_freq {columns}'] = 1

for columns in naver_priority:
    df[f'naver_priority {columns}'] = 1

# %%
df.reset_index()
# Out:
# Empty DataFrame
# Columns: [index, oxford_level A1, oxford_level A2, oxford_level B1, oxford_level B2, oxford_level C1, lexile_grade 1, lexile_grade 2, lexile_grade 3, lexile_grade 4, lexile_grade 5, lexile_grade 6, lexile_grade 9, lexile_category social_studies, lexile_category general, lexile_category science, lexile_category math, awsl, toefl, tsl, bsl, ngsl_freq A1, ngsl_freq A2, ngsl_freq A3, ngsl_freq A4, ngsl_freq B1, ngsl_freq B2, ngsl_freq B3, ngsl_freq C1, ngsl_freq C2, ngsl_freq C3, ngsl_freq C4, ngsl_freq C5, ngsl_sp_freq A1, ngsl_sp_freq A2, ngsl_sp_freq A3, ngsl_sp_freq A4, ngsl_sp_freq B1, ngsl_sp_freq B2, ngsl_sp_freq B3, ngsl_sp_freq C1, ngsl_sp_freq C2, ngsl_sp_freq C3, naver_priority 2, naver_priority 1, naver_priority 0]
# Index: []
#
# [0 rows x 46 columns]

# %%
columns = []

for i in oxford_level:
    columns.append(['oxford_level', i])

for i in lexile_grade:
    columns.append(['lexile_grade', i])

for i in lexile_category:
    columns.append(['lexile_category', i])

columns.append(['awsl', 'Y'])
columns.append(['toefl', 'Y'])
columns.append(['tsl', 'Y'])
columns.append(['bsl', 'Y'])

for i in ngsl_freq:
    columns.append(['ngsl_freq', i])

for i in ngsl_sp_freq:
    columns.append(['ngsl_sp_freq', i])

for i in naver_priority:
    columns.append(['naver_priority', i])

rows = []

for i in oxford_level:
    rows.append(['oxford_level', i])

for i in lexile_grade:
    rows.append(['lexile_grade', i])

for i in lexile_category:
    rows.append(['lexile_category', i])

rows.append(['awsl', 'Y'])
rows.append(['toefl', 'Y'])
rows.append(['tsl', 'Y'])
rows.append(['bsl', 'Y'])

for i in ngsl_freq:
    rows.append(['ngsl_freq', i])

for i in ngsl_sp_freq:
    rows.append(['ngsl_sp_freq', i])

for i in naver_priority:
    rows.append(['naver_priority', i])

# %%
for row in rows:
    result = []

    temp_word_db_df = word_db_df[word_db_df[row[0]] == row[1]]

    for column in columns:
        result.append(round(len(temp_word_db_df[temp_word_db_df[column[0]] == column[1]]) / len(temp_word_db_df) * 100,2))

    df.loc[f'{row[0]}, {row[1]}'] = result

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                  oxford_level A1  oxford_level A2  \
# oxford_level, A1                             100                0
# oxford_level, A2                               0              100
# oxford_level, B1                               0                0
# oxford_level, B2                               0                0
# oxford_level, C1                               0                0
# lexile_grade, 1                               17               23
# lexile_grade, 2                                5               14
# lexile_grade, 3                                3               10
# lexile_grade, 4                                1                7
# lexile_grade, 5                                0                3
# lexile_grade, 6                                0                0
# lexile_grade, 9                                0                0
# lexile_category, social_studies                1                2
# ...

# %%
# df.to_csv(f'../words/final_datasets/All_words_df.csv')

# %%
# data = pd.read_csv('../words/final_datasets/All_words_df.csv')
# data

# %%
plt.pcolor(df)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.title('Heatmap by plt.pcolor()', fontsize=20)
plt.xlabel('columns', fontsize=14)
plt.ylabel('index', fontsize=14)
plt.colorbar()
