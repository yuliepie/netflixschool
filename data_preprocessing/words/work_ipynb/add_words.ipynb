# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 50)
pd.set_option('display.min_rows', 50)

# %%
words_df = pd.read_csv('../words_refined/basic_words.csv')
words_df[['oxford_level', 'oxford_version', 'lexile_grade', 'lexile_category', 'awsl', 'toefl', 'tsl', 'bsl', 'ngsl_freq', 'ngsl_sp_freq', 'naver_priority', 'lemmetized']] = np.nan

words_df["Word"] = words_df["Word"].str.lower()
words_df = words_df.set_index('Word')
words_df = words_df.sort_index()

words_df
# Out:
#             oxford_level  oxford_version  lexile_grade  lexile_category  awsl  \
# Word
# abandon              NaN             NaN           NaN              NaN   NaN
# abdomen              NaN             NaN           NaN              NaN   NaN
# able                 NaN             NaN           NaN              NaN   NaN
# abnormal             NaN             NaN           NaN              NaN   NaN
# aboard               NaN             NaN           NaN              NaN   NaN
# abolish              NaN             NaN           NaN              NaN   NaN
# abort                NaN             NaN           NaN              NaN   NaN
# about                NaN             NaN           NaN              NaN   NaN
# above                NaN             NaN           NaN              NaN   NaN
# abroad               NaN             NaN           NaN              NaN   NaN
# abrupt               NaN             NaN           NaN              NaN   NaN
# absence              NaN             NaN           NaN              NaN   NaN
# absent               NaN             NaN           NaN              NaN   NaN
# absolute             NaN             NaN           NaN              NaN   NaN
# absorb               NaN             NaN           NaN              NaN   NaN
# abstract             NaN             NaN           NaN              NaN   NaN
# absurd               NaN             NaN           NaN              NaN   NaN
# abundant             NaN             NaN           NaN              NaN   NaN
# abuse                NaN             NaN           NaN              NaN   NaN
# academy              NaN             NaN           NaN              NaN   NaN
# accelerate           NaN             NaN           NaN              NaN   NaN
# accent               NaN             NaN           NaN              NaN   NaN
# accept               NaN             NaN           NaN              NaN   NaN
# access               NaN             NaN           NaN              NaN   NaN
# accessory            NaN             NaN           NaN              NaN   NaN
# ...                  ...             ...           ...              ...   ...
# would                NaN             NaN           NaN              NaN   NaN
# wound                NaN             NaN           NaN              NaN   NaN
# wrap                 NaN             NaN           NaN              NaN   NaN
# wreck                NaN             NaN           NaN              NaN   NaN
# wrestle              NaN             NaN           NaN              NaN   NaN
# wrinkle              NaN             NaN           NaN              NaN   NaN
# wrist                NaN             NaN           NaN              NaN   NaN
# write                NaN             NaN           NaN              NaN   NaN
# wrong                NaN             NaN           NaN              NaN   NaN
# yacht                NaN             NaN           NaN              NaN   NaN
# yard                 NaN             NaN           NaN              NaN   NaN
# year                 NaN             NaN           NaN              NaN   NaN
# yell                 NaN             NaN           NaN              NaN   NaN
# yellow               NaN             NaN           NaN              NaN   NaN
# yes                  NaN             NaN           NaN              NaN   NaN
# yesterday            NaN             NaN           NaN              NaN   NaN
# yet                  NaN             NaN           NaN              NaN   NaN
# yield                NaN             NaN           NaN              NaN   NaN
# you                  NaN             NaN           NaN              NaN   NaN
# young                NaN             NaN           NaN              NaN   NaN
# youth                NaN             NaN           NaN              NaN   NaN
# zero                 NaN             NaN           NaN              NaN   NaN
# zip                  NaN             NaN           NaN              NaN   NaN
# zone                 NaN             NaN           NaN              NaN   NaN
# zoo                  NaN             NaN           NaN              NaN   NaN
#
#             toefl  tsl  bsl  ngsl_freq  ngsl_sp_freq  naver_priority  \
# Word
# abandon       NaN  NaN  NaN        NaN           NaN             NaN
# abdom
# academy            NaN
# accelerate         NaN
# accent             NaN
# accept             NaN
# access             NaN
# accessory          NaN
# ...                ...
# would              NaN
# wound              NaN
# wrap               NaN
# wreck              NaN
# wrestle            NaN
# wrinkle            NaN
# wrist              NaN
# write              NaN
# wrong              NaN
# yacht              NaN
# yard               NaN
# year               NaN
# yell               NaN
# yellow             NaN
# yes                NaN
# yesterday          NaN
# yet                NaN
# yield              NaN
# you                NaN
# young              NaN
# youth              NaN
# zero               NaN
# zip                NaN
# zone               NaN
# zoo                NaN
#
# [4998 rows x 12 columns]

# %% [markdown]
# ## Oxford

# %%
ox3000 = pd.read_csv('../words_refined/ox_3000_american.csv', index_col='Word')
ox3000
ox5000 = pd.read_csv('../words_refined/ox_5000_american.csv', index_col='Word')
ox5000

ox_df = ox3000.append(ox5000)
ox_df
ox_df = ox_df.rename(columns={'Level': 'oxford_level', 'Version': 'oxford_version'})
ox_df = ox_df[~ox_df.index.duplicated(keep='first')]
ox_df

# add oxford word rows that are not in words_df
words_df = pd.concat([words_df, ox_df[~ox_df.index.isin(words_df.index)]])
# for words that exist already, update oxford details
words_df.update(ox_df)
words_df = words_df.sort_index()

words_df
# Out:
#            oxford_level  oxford_version  lexile_grade  lexile_category  awsl  \
# Word
# abandon              B2          3000.0           NaN              NaN   NaN
# abdomen             NaN             NaN           NaN              NaN   NaN
# ability              A2          3000.0           NaN              NaN   NaN
# able                 A2          3000.0           NaN              NaN   NaN
# abnormal            NaN             NaN           NaN              NaN   NaN
# aboard              NaN             NaN           NaN              NaN   NaN
# abolish              C1          5000.0           NaN              NaN   NaN
# abort               NaN             NaN           NaN              NaN   NaN
# abortion             C1          5000.0           NaN              NaN   NaN
# about                A1          3000.0           NaN              NaN   NaN
# above                A1          3000.0           NaN              NaN   NaN
# abroad               B2          3000.0           NaN              NaN   NaN
# abrupt              NaN             NaN           NaN              NaN   NaN
# absence              C1          5000.0           NaN              NaN   NaN
# absent               C1          5000.0           NaN              NaN   NaN
# absolute             B2          3000.0           NaN              NaN   NaN
# absolutely           B1          3000.0           NaN              NaN   NaN
# absorb               B2          5000.0           NaN              NaN   NaN
# abstract             B2          5000.0           NaN              NaN   NaN
# absurd               C1          5000.0           NaN              NaN   NaN
# abundant            NaN             NaN           NaN              NaN   NaN
# abuse                C1          5000.0           NaN              NaN   NaN
# academic             B1          3000.0           NaN              NaN   NaN
# academy              C1          5000.0           NaN              NaN   NaN
# accelerate           C1          5000.0           NaN              NaN   NaN
# ...                 ...             ...           ...              ...   ...
# write                A1          3000.0           NaN              NaN   NaN
# writer               A1          3000.0           NaN              NaN   NaN
# writing              A1          3000.0           NaN              NaN   NaN
# written              B1          3000.0           NaN              NaN   NaN
# wrong                A1          3000.0           NaN              NaN   NaN
# yacht               NaN             NaN           NaN              NaN   NaN
# yard                 A1          3000.0           NaN              NaN   NaN
# yeah                 A1          3000.0           NaN              NaN   NaN
# year                 A1          3000.0           NaN              NaN   NaN
# yell                 C1          5000.0           NaN              NaN   NaN
# yellow               A1          3000.0           NaN              NaN   NaN
# yes                  A1          3000.0           NaN              NaN   NaN
# yours         NaN  NaN  NaN        NaN           NaN             NaN
# yourself      NaN  NaN  NaN        NaN           NaN             NaN
# youth         NaN  NaN  NaN        NaN           NaN             NaN
# zero          NaN  NaN  NaN        NaN           NaN             NaN
# zip           NaN  NaN  NaN        NaN           NaN             NaN
# zone          NaN  NaN  NaN        NaN           NaN             NaN
# zoo           NaN  NaN  NaN        NaN           NaN             NaN
#
#             lemmetized
# Word
# abandon            NaN
# abdomen            NaN
# ability            NaN
# able               NaN
# abnormal           NaN
# aboard             NaN
# abolish            NaN
# abort              NaN
# abortion           NaN
# about              NaN
# above              NaN
# abroad             NaN
# abrupt             NaN
# absence            NaN
# absent             NaN
# absolute           NaN
# absolutely         NaN
# absorb             NaN
# abstract           NaN
# absurd             NaN
# abundant           NaN
# abuse              NaN
# academic           NaN
# academy            NaN
# accelerate         NaN
# ...                ...
# write              NaN
# writer             NaN
# writing            NaN
# written            NaN
# wrong              NaN
# yacht              NaN
# yard               NaN
# yeah               NaN
# year               NaN
# yell               NaN
# yellow             NaN
# yes                NaN
# yesterday          NaN
# yet                NaN
# yield              NaN
# you                NaN
# young              NaN
# your               NaN
# yours              NaN
# yourself           NaN
# youth              NaN
# zero               NaN
# zip                NaN
# zone               NaN
# zoo                NaN
#
# [6466 rows x 12 columns]

# %% [markdown]
# ## Lexile

# %%
lex_df = pd.read_csv('../words_refined/lexiles_no_duplicates.csv', index_col='Word')
lex_df = lex_df.rename(columns={'Domain': 'lexile_category', 'Level': 'lexile_grade'})
lex_df.index = lex_df.index.str.lower()
words_df = pd.concat([words_df, lex_df[~lex_df.index.isin(words_df.index)]])
# words_df[words_df.index.duplicated(keep=False)]
words_df.update(lex_df)
words_df.sort_index(inplace=True)

lex_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category  awsl  \
# Word
# abandon                B2          3000.0           NaN             NaN   NaN
# abbot                 NaN             NaN           9.0  social_studies   NaN
# abbreviate            NaN             NaN           9.0         general   NaN
# abbreviation          NaN             NaN           6.0         general   NaN
# abdicate              NaN             NaN           9.0  social_studies   NaN
# abdomen               NaN             NaN           6.0         science   NaN
# abdominal             NaN             NaN           9.0         science   NaN
# aberration            NaN             NaN           9.0         science   NaN
# ability                A2          3000.0           4.0         general   NaN
# abiotic               NaN             NaN           4.0         science   NaN
# able                   A2          3000.0           NaN             NaN   NaN
# ably                  NaN             NaN           9.0         general   NaN
# abnormal              NaN             NaN           6.0         science   NaN
# abnormally            NaN             NaN           9.0         science   NaN
# aboard                NaN             NaN           NaN             NaN   NaN
# abode                 NaN             NaN           6.0  social_studies   NaN
# abolish                C1          5000.0           4.0  social_studies   NaN
# abolition             NaN             NaN           5.0  social_studies   NaN
# abolitionism          NaN             NaN           9.0  social_studies   NaN
# abolitionist          NaN             NaN           4.0  social_studies   NaN
# abomination           NaN             NaN           6.0  social_studies   NaN
# aboriginal            NaN             NaN           9.0  social_studies   NaN
# aborigine             NaN             NaN           6.0  social_studies   NaN
# abort                 NaN             NaN           NaN             NaN   NaN
# abortion               C1          5000.0           NaN             NaN   NaN
# ...                   ...             ...           ...             ...   ...
# yes                    A1          3000.0           NaN             NaN   NaN
# your            NaN  NaN  NaN        NaN           NaN             NaN
# yours           NaN  NaN  NaN        NaN           NaN             NaN
# yourself        NaN  NaN  NaN        NaN           NaN             NaN
# youth           NaN  NaN  NaN        NaN           NaN             NaN
# yucca           NaN  NaN  NaN        NaN           NaN             NaN
# zeal            NaN  NaN  NaN        NaN           NaN             NaN
# zealot          NaN  NaN  NaN        NaN           NaN             NaN
# zebra           NaN  NaN  NaN        NaN           NaN             NaN
# zero            NaN  NaN  NaN        NaN           NaN             NaN
# ziggurat        NaN  NaN  NaN        NaN           NaN             NaN
# zinc            NaN  NaN  NaN        NaN           NaN             NaN
# zip             NaN  NaN  NaN        NaN           NaN             NaN
# zone            NaN  NaN  NaN        NaN           NaN             NaN
# zoo             NaN  NaN  NaN        NaN           NaN             NaN
# zoologist       NaN  NaN  NaN        NaN           NaN             NaN
# zooplankton     NaN  NaN  NaN        NaN           NaN             NaN
# zulu            NaN  NaN  NaN        NaN           NaN             NaN
# zygote          NaN  NaN  NaN        NaN           NaN             NaN
#
#               lemmetized
# Word
# abandon              NaN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdomen              NaN
# abdominal            NaN
# aberration           NaN
# ability              NaN
# abiotic              NaN
# able                 NaN
# ably                 NaN
# abnormal             NaN
# abnormally           NaN
# aboard               NaN
# abode                NaN
# abolish              NaN
# abolition            NaN
# abolitionism         NaN
# abolitionist         NaN
# abomination          NaN
# aboriginal           NaN
# aborigine            NaN
# abort                NaN
# abortion             NaN
# ...                  ...
# yes                  NaN
# yesterday            NaN
# yet                  NaN
# yield                NaN
# yolk                 NaN
# you                  NaN
# young                NaN
# your                 NaN
# yours                NaN
# yourself             NaN
# youth                NaN
# yucca                NaN
# zeal                 NaN
# zealot               NaN
# zebra                NaN
# zero                 NaN
# ziggurat             NaN
# zinc                 NaN
# zip                  NaN
# zone                 NaN
# zoo                  NaN
# zoologist            NaN
# zooplankton          NaN
# zulu                 NaN
# zygote               NaN
#
# [10341 rows x 12 columns]

# %% [markdown]
# ## TOEFL

# %%
toefl_df = pd.read_csv('../words_refined/toefl.csv', index_col='Word')
toefl_df['toefl'] = 'Y'
toefl_df.index = toefl_df.index.str.lower()
words_df = pd.concat([words_df, toefl_df[~toefl_df.index.isin(words_df.index)]])
words_df.update(toefl_df)
words_df.sort_index(inplace=True)

n = words_df[words_df['toefl'] == 'Y']
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category  awsl  \
# Word
# abandon                B2          3000.0           NaN             NaN   NaN
# abbot                 NaN             NaN           9.0  social_studies   NaN
# abbreviate            NaN             NaN           9.0         general   NaN
# abbreviation          NaN             NaN           6.0         general   NaN
# abdicate              NaN             NaN           9.0  social_studies   NaN
# abdomen               NaN             NaN           6.0         science   NaN
# abdominal             NaN             NaN           9.0         science   NaN
# aberration            NaN             NaN           9.0         science   NaN
# abigail               NaN             NaN           NaN             NaN   NaN
# ability                A2          3000.0           4.0         general   NaN
# abiotic               NaN             NaN           4.0         science   NaN
# able                   A2          3000.0           NaN             NaN   NaN
# ably                  NaN             NaN           9.0         general   NaN
# abnormal              NaN             NaN           6.0         science   NaN
# abnormally            NaN             NaN           9.0         science   NaN
# aborigine      NaN  NaN  NaN        NaN           NaN             NaN
# abort          NaN  NaN  NaN        NaN           NaN             NaN
# ...            ...  ...  ...        ...           ...             ...
# you'd            Y  NaN  NaN        NaN           NaN             NaN
# young          NaN  NaN  NaN        NaN           NaN             NaN
# your           NaN  NaN  NaN        NaN           NaN             NaN
# yours            Y  NaN  NaN        NaN           NaN             NaN
# yourself       NaN  NaN  NaN        NaN           NaN             NaN
# youth          NaN  NaN  NaN        NaN           NaN             NaN
# yucca          NaN  NaN  NaN        NaN           NaN             NaN
# zeal           NaN  NaN  NaN        NaN           NaN             NaN
# zealand          Y  NaN  NaN        NaN           NaN             NaN
# zealot         NaN  NaN  NaN        NaN           NaN             NaN
# zebra          NaN  NaN  NaN        NaN           NaN             NaN
# zero           NaN  NaN  NaN        NaN           NaN             NaN
# ziggurat       NaN  NaN  NaN        NaN           NaN             NaN
# zigzag           Y  NaN  NaN        NaN           NaN             NaN
# zimbabwe         Y  NaN  NaN        NaN           NaN             NaN
# zinc             Y  NaN  NaN        NaN           NaN             NaN
# zip            NaN  NaN  NaN        NaN           NaN             NaN
# zone           NaN  NaN  NaN        NaN           NaN             NaN
# zoo              Y  NaN  NaN        NaN           NaN             NaN
# zoologist      NaN  NaN  NaN        NaN           NaN             NaN
# zoology          Y  NaN  NaN        NaN           NaN             NaN
# zooplankton    NaN  NaN  NaN        NaN           NaN             NaN
# zulu           NaN  NaN  NaN        NaN           NaN             NaN
# zuni             Y  NaN  NaN        NaN           NaN             NaN
# zygote         NaN  NaN  NaN        NaN           NaN             NaN
#
#               lemmetized
# Word
# abandon              NaN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdomen              NaN
# abdominal            NaN
# aberration           NaN
# abigail              NaN
# ability              NaN
# abiotic              NaN
# able                 NaN
# ably                 NaN
# abnormal             NaN
# abnormally           NaN
# aboard               NaN
# abode                NaN
# abolish              NaN
# abolition            NaN
# abolitionism         NaN
# abolitionist         NaN
# abomination          NaN
# aboriginal           NaN
# aborigine            NaN
# abort                NaN
# ...                  ...
# you'd                NaN
# young                NaN
# your                 NaN
# yours                NaN
# yourself             NaN
# youth                NaN
# yucca                NaN
# zeal                 NaN
# zealand              NaN
# zealot               NaN
# zebra                NaN
# zero                 NaN
# ziggurat             NaN
# zigzag               NaN
# zimbabwe             NaN
# zinc                 NaN
# zip                  NaN
# zone                 NaN
# zoo                  NaN
# zoologist            NaN
# zoology              NaN
# zooplankton          NaN
# zulu                 NaN
# zuni                 NaN
# zygote               NaN
#
# [11660 rows x 12 columns]

# %% [markdown]
# ## TSL

# %%
tsl_df = pd.read_csv('../words_refined/tsl_with_lemmas.csv', index_col='Word')
tsl_df = tsl_df.drop(columns='Lemmas')
tsl_df['tsl'] = 'Y'
tsl_df.index = tsl_df.index.str.lower()

words_df = pd.concat([words_df, tsl_df[~tsl_df.index.isin(words_df.index)]])
words_df.update(tsl_df)
words_df.sort_index(inplace=True)

n = words_df[words_df['tsl'] == 'Y']

tsl_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_
# [11904 rows x 12 columns]

# %% [markdown]
# ## BSL

# %%
bsl_df = pd.read_csv('../words_refined/bsl_with_lemmas.csv', index_col='Word')
bsl_df = bsl_df.drop(columns='Lemmas')
bsl_df['bsl'] = 'Y'
bsl_df.index = bsl_df.index.str.lower()

words_df = pd.concat([words_df, bsl_df[~bsl_df.index.isin(words_df.index)]])
words_df.update(bsl_df)
words_df.sort_index(inplace=True)

n = words_df[words_df['bsl'] == 'Y']

# get rid of NaN
words_df = words_df[words_df.index.notnull()]
bsl_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category  awsl  \
# Word
# abandon                B2          3000.0           NaN             NaN   NaN
# abbot                 NaN             NaN           9.0  social_studies   NaN
# abbreviate            NaN             NaN           9.0         general   NaN
# abbreviation          NaN             NaN           6.0         general   NaN
# abdicate              NaN             NaN           9.0  social_studies   NaN
# abdomen               NaN             NaN           6.0         science   NaN
# abdominal             NaN             NaN           9.0         science   NaN
# aberration            NaN             NaN           9.0         science   NaN
# abide                 NaN             NaN           NaN             NaN   NaN
# abigail               NaN             NaN           NaN             NaN   NaN
# ability                A2          3000.0           4.0         general   NaN
# abiotic               NaN             NaN           4.0         science   NaN
# able                   A2          3000.0           NaN             NaN   NaN
# ably                  NaN             NaN           9.0         general   NaN
# abnormal              NaN             NaN           6.0         science   NaN
# abnormally            NaN             NaN           9.0         science   NaN
# aboard                NaN             NaN           NaN             NaN   NaN
# abode                 NaN             NaN           6.0  social_studies   NaN
# abolish                C1          5000.0           4.0  social_studies   NaN
# abolition             NaN             NaN           5.0  social_studies   NaN
# abolitionism          NaN             NaN           9.0  social_studies   NaN
# abolitionist          NaN             NaN           4.0  social_studies   NaN
# abomination           NaN             NaN           6.0  social_studies   NaN
# aboriginal            NaN             NaN           9.0  social_studies   NaN
# aborigine             NaN             NaN           6.0  social_studies   NaN
# ...                   ...             ...           ...             ...   ...
# young                  A1          3000.0           NaN             NaN   NaN
# your                   A1          3000.0           NaN             NaN   NaN
# yours                  A2          3000.0           NaN             NaN   NaN
# yourself               A1          3000.0           NaN             NaN   NaN
# youth                  B1          3000.0           NaN             NaN   NaN
# yuan                  NaN             NaN           NaN             NaN   NaN
# yucca                 NaN             NaN           9.0         science   NaN
# zeal                  NaN             NaN           9.0  social_studies   NaN
# zealand               NaN             NaN           NaN             NaN   NaN
# zealot                NaN             NaN           6.0  social_studies   NaN
# zebra                 NaN             NaN           2.0         science   NaN
# zero                   A2          3000.0           3.0            math   NaN
# ziggurat              NaN             NaN           6.0  social_studies   NaN
# zigzag                NaN             NaN           NaN             NaN   NaN
# zimbabwe              NaN             NaN           NaN             NaN   NaN
# zinc                  NaN             NaN           5.0         science   NaN
# zip                   NaN             NaN           NaN             NaN   NaN
# zone                   B2          3000.0           2.0         science   NaN
# zoo                   NaN             NaN           NaN             NaN   NaN
# zoologist             NaN             NaN           5.0         science   NaN
# zoology               NaN             NaN           NaN             NaN   NaN
# zooplankton           NaN             NaN           9.0         science   NaN
# zulu                  NaN             NaN           9.0  social_studies   NaN
# zuni                  NaN             NaN           NaN             NaN   NaN
# zygote                NaN             NaN           6.0         science   NaN
#
#              toefl  tsl  bsl  ngsl_freq  ngsl_sp_freq  naver_priority  \
# Word
aN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdomen              NaN
# abdominal            NaN
# aberration           NaN
# abide                NaN
# abigail              NaN
# ability              NaN
# abiotic              NaN
# able                 NaN
# ably                 NaN
# abnormal             NaN
# abnormally           NaN
# aboard               NaN
# abode                NaN
# abolish              NaN
# abolition            NaN
# abolitionism         NaN
# abolitionist         NaN
# abomination          NaN
# aboriginal           NaN
# aborigine            NaN
# ...                  ...
# young                NaN
# your                 NaN
# yours                NaN
# yourself             NaN
# youth                NaN
# yuan                 NaN
# yucca                NaN
# zeal                 NaN
# zealand              NaN
# zealot               NaN
# zebra                NaN
# zero                 NaN
# ziggurat             NaN
# zigzag               NaN
# zimbabwe             NaN
# zinc                 NaN
# zip                  NaN
# zone                 NaN
# zoo                  NaN
# zoologist            NaN
# zoology              NaN
# zooplankton          NaN
# zulu                 NaN
# zuni                 NaN
# zygote               NaN
#
# [12122 rows x 12 columns]

# %% [markdown]
# ## AWSL

# %%
awsl_df = pd.read_csv("../words_refined/awsl_with_lemmas.csv", index_col='Word')
awsl_df = awsl_df.drop(columns="Lemmas")
awsl_df['awsl'] = 'Y'
awsl_df.index = awsl_df.index.str.lower()

awsl_df = awsl_df[~awsl_df.index.duplicated(keep='first')]

words_df = pd.concat([words_df, awsl_df[~awsl_df.index.isin(words_df.index)]])
words_df.update(awsl_df)
words_df.sort_index(inplace=True)

n = words_df[words_df['awsl'] == 'Y']

awsl_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                     NaN             NaN           NaN             NaN    Y
# abandon                B2          3000.0           NaN             NaN  NaN
# abbot                 NaN             NaN           9.0  social_studies  NaN
# abbreviate            NaN             NaN           9.0         general  NaN
# abbreviation          NaN             NaN           6.0         general  NaN
# abdicate              NaN             NaN           9.0  social_studies  NaN
# abdomen               NaN             NaN           6.0         science  NaN
# abdominal             NaN             NaN           9.0         science  NaN
# aberration            NaN             NaN           9.0         science  NaN
# abide                 NaN             NaN           NaN             NaN  NaN
# abigail               NaN             NaN           NaN             NaN  NaN
# ability                A2          3000.0           4.0         general  NaN
# abiotic               NaN             NaN           4.0         science  NaN
# able                   A2          3000.0           NaN             NaN    Y
# ably                  NaN             NaN           9.0         general  NaN
# abnormal              NaN             NaN           6.0         science  NaN
# abnormally            NaN             NaN           9.0         science  NaN
# aboard                NaN             NaN           NaN             NaN  NaN
# abode                 NaN             NaN           6.0  social_studies  NaN
# abolish                C1          5000.0           4.0  social_studies  NaN
# abolition             NaN             NaN           5.0  social_studies  NaN
# abolitionism          NaN             NaN           9.0  social_studies  NaN
# abolitionist          NaN             NaN           4.0  social_studies  NaN
# abomination           NaN             NaN           6.0  social_studies  NaN
# aboriginal            NaN             NaN           9.0  social_studies  NaN
# ...                   ...             ...           ...             ...  ...
# young                  A1          3000.0           NaN             NaN    Y
# your                   A1          3000.0           NaN             NaN  NaN
# yours                  A2          3000.0           NaN             NaN  NaN
# yourself               A1          3000.0           NaN             NaN  NaN
# youth                  B1          3000.0           NaN             NaN  NaN
# yuan                  NaN             NaN           NaN             NaN  NaN
# yucca                 NaN             NaN           9.0         science  NaN
# zeal                  NaN             NaN           9.0  social_studies  NaN
# zealand               NaN             NaN           NaN             NaN  NaN
# zealot                NaN             NaN           6.0  social_studies  NaN
# zebra                 NaN             NaN           2.0         science  NaN
# zero                   A2          3000.0           3.0            math    Y
# zip            NaN  NaN  NaN        NaN           NaN             NaN
# zone           NaN  NaN  NaN        NaN           NaN             NaN
# zoo              Y    Y  NaN        NaN           NaN             NaN
# zoologist      NaN  NaN  NaN        NaN           NaN             NaN
# zoology          Y  NaN  NaN        NaN           NaN             NaN
# zooplankton    NaN  NaN  NaN        NaN           NaN             NaN
# zulu           NaN  NaN  NaN        NaN           NaN             NaN
# zuni             Y  NaN  NaN        NaN           NaN             NaN
# zygote         NaN  NaN  NaN        NaN           NaN             NaN
#
#               lemmetized
# Word
# a                    NaN
# abandon              NaN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdomen              NaN
# abdominal            NaN
# aberration           NaN
# abide                NaN
# abigail              NaN
# ability              NaN
# abiotic              NaN
# able                 NaN
# ably                 NaN
# abnormal             NaN
# abnormally           NaN
# aboard               NaN
# abode                NaN
# abolish              NaN
# abolition            NaN
# abolitionism         NaN
# abolitionist         NaN
# abomination          NaN
# aboriginal           NaN
# ...                  ...
# young                NaN
# your                 NaN
# yours                NaN
# yourself             NaN
# youth                NaN
# yuan                 NaN
# yucca                NaN
# zeal                 NaN
# zealand              NaN
# zealot               NaN
# zebra                NaN
# zero                 NaN
# ziggurat             NaN
# zigzag               NaN
# zimbabwe             NaN
# zinc                 NaN
# zip                  NaN
# zone                 NaN
# zoo                  NaN
# zoologist            NaN
# zoology              NaN
# zooplankton          NaN
# zulu                 NaN
# zuni                 NaN
# zygote               NaN
#
# [12128 rows x 12 columns]

# %% [markdown]
# ## NGSL

# %%
ngsl_df = pd.read_csv('../words_refined/ngsl_freq.csv', index_col='Word')
ngsl_df = ngsl_df.rename(columns={'Frequency': 'ngsl_freq'})
ngsl_df.sort_index(inplace=True)
ngsl_df = ngsl_df[ngsl_df.index.notnull()]
ngsl_df.index = ngsl_df.index.str.lower()

words_df = pd.concat([words_df, ngsl_df[~ngsl_df.index.isin(words_df.index)]])
words_df.update(ngsl_df)
words_df.sort_index(inplace=True)

ngsl_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                     NaN             NaN           NaN             NaN    Y
# aback                 NaN             NaN           NaN             NaN  NaN
# abacus                NaN             NaN           NaN             NaN  NaN
# abalone               NaN             NaN           NaN             NaN  NaN
# abandon                B2          3000.0           NaN             NaN  NaN
# abandonment           NaN             NaN           NaN             NaN  NaN
# abase                 NaN             NaN           NaN             NaN  NaN
# abash                 NaN             NaN           NaN             NaN  NaN
# abate                 NaN             NaN           NaN             NaN  NaN
# abatement             NaN             NaN           NaN             NaN  NaN
# abattoir              NaN             NaN           NaN             NaN  NaN
# abaya                 NaN             NaN           NaN             NaN  NaN
# abbacy                NaN             NaN           NaN             NaN  NaN
# abbess                NaN             NaN           NaN             NaN  NaN
# abbey                 NaN             NaN           NaN             NaN  NaN
# abbot                 NaN             NaN           9.0  social_studies  NaN
# abbreviate            NaN             NaN           9.0         general  NaN
# abbreviation          NaN             NaN           6.0         general  NaN
# abdicate              NaN             NaN           9.0  social_studies  NaN
# abdication            NaN             NaN           NaN             NaN  NaN
# abdomen               NaN             NaN           6.0         science  NaN
# abdominal             NaN             NaN           9.0         science  NaN
# abduct                NaN             NaN           NaN             NaN  NaN
# zodiac         NaN  NaN  NaN        C2           NaN             NaN
# zombie         NaN  NaN  NaN        C1           NaN             NaN
# zonal          NaN  NaN  NaN        C3           NaN             NaN
# zonation       NaN  NaN  NaN        C5           NaN             NaN
# zone           NaN  NaN  NaN        A3           NaN             NaN
# zoo              Y    Y  NaN        A4           NaN             NaN
# zookeeper      NaN  NaN  NaN        C3           NaN             NaN
# zoological     NaN  NaN  NaN        C3           NaN             NaN
# zoologist      NaN  NaN  NaN        C2           NaN             NaN
# zoology          Y  NaN  NaN        C2           NaN             NaN
# zoom           NaN  NaN  NaN        B2           NaN             NaN
# zoonotic       NaN  NaN  NaN        C4           NaN             NaN
# zooplankton    NaN  NaN  NaN        C4           NaN             NaN
# zucchini       NaN  NaN  NaN        C2           NaN             NaN
# zulu           NaN  NaN  NaN       NaN           NaN             NaN
# zuni             Y  NaN  NaN       NaN           NaN             NaN
# zygomatic      NaN  NaN  NaN        C4           NaN             NaN
# zygomorphic    NaN  NaN  NaN        C4           NaN             NaN
# zygosity       NaN  NaN  NaN        C4           NaN             NaN
# zygote         NaN  NaN  NaN        C1           NaN             NaN
# zygotic        NaN  NaN  NaN        C3           NaN             NaN
# émigré         NaN  NaN  NaN        C2           NaN             NaN
#
#               lemmetized
# Word
# a                    NaN
# aback                NaN
# abacus               NaN
# abalone              NaN
# abandon              NaN
# abandonment          NaN
# abase                NaN
# abash                NaN
# abate                NaN
# abatement            NaN
# abattoir             NaN
# abaya                NaN
# abbacy               NaN
# abbess               NaN
# abbey                NaN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdication           NaN
# abdomen              NaN
# abdominal            NaN
# abduct               NaN
# abduction            NaN
# abductor             NaN
# ...                  ...
# zirconia             NaN
# zither               NaN
# zloty                NaN
# zodiac               NaN
# zombie               NaN
# zonal                NaN
# zonation             NaN
# zone                 NaN
# zoo                  NaN
# zookeeper            NaN
# zoological           NaN
# zoologist            NaN
# zoology              NaN
# zoom                 NaN
# zoonotic             NaN
# zooplankton          NaN
# zucchini             NaN
# zulu                 NaN
# zuni                 NaN
# zygomatic            NaN
# zygomorphic          NaN
# zygosity             NaN
# zygote               NaN
# zygotic              NaN
# émigré               NaN
#
# [32771 rows x 12 columns]

# %% [markdown]
# ## NGSL-SP

# %%
ngsl_sp_df = pd.read_csv('../words_refined/ngsl_sp_freq.csv', index_col='Word')
ngsl_sp_df = ngsl_sp_df.rename(columns={'Frequency': 'ngsl_sp_freq'})
ngsl_sp_df.sort_index(inplace=True)
ngsl_sp_df = ngsl_sp_df[ngsl_sp_df.index.notnull()]
ngsl_sp_df.index = ngsl_sp_df.index.str.lower()

words_df = pd.concat([words_df, ngsl_sp_df[~ngsl_sp_df.index.isin(words_df.index)]])
words_df.update(ngsl_sp_df)
words_df.sort_index(inplace=True)

ngsl_sp_df
words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_
# abbacy         NaN  NaN  NaN        C4          NaN             NaN
# abbess         NaN  NaN  NaN        C3          NaN             NaN
# abbey          NaN  NaN  NaN        B3           C1             NaN
# abbot          NaN  NaN  NaN        C1           C3             NaN
# abbreviate       Y  NaN  NaN        B3           C1             NaN
# abbreviation     Y  NaN  NaN        B3           C1             NaN
# abdicate       NaN  NaN  NaN        C1           C1             NaN
# abdication     NaN  NaN  NaN        C2           C2             NaN
# abdomen          Y  NaN  NaN        B3           B3             NaN
# abdominal      NaN  NaN  NaN        A4           A4             NaN
# abduct         NaN  NaN  NaN        B3           B2             NaN
# abduction      NaN  NaN  NaN        C1           B3             NaN
# ...            ...  ...  ...       ...          ...             ...
# zirconia       NaN  NaN  NaN        C4          NaN             NaN
# zither         NaN  NaN  NaN        C3           C2             NaN
# zloty          NaN  NaN  NaN        C3          NaN             NaN
# zodiac         NaN  NaN  NaN        C2          NaN             NaN
# zombie         NaN  NaN  NaN        C1           C1             NaN
# zonal          NaN  NaN  NaN        C3          NaN             NaN
# zonation       NaN  NaN  NaN        C5          NaN             NaN
# zone           NaN  NaN  NaN        A3           A2             NaN
# zoo              Y    Y  NaN        A4           B1             NaN
# zookeeper      NaN  NaN  NaN        C3           C1             NaN
# zoological     NaN  NaN  NaN        C3          NaN             NaN
# zoologist      NaN  NaN  NaN        C2           C3             NaN
# zoology          Y  NaN  NaN        C2           C2             NaN
# zoom           NaN  NaN  NaN        B2           B2             NaN
# zoonotic       NaN  NaN  NaN        C4          NaN             NaN
# zooplankton    NaN  NaN  NaN        C4          NaN             NaN
# zucchini       NaN  NaN  NaN        C2           C1             NaN
# zulu           NaN  NaN  NaN       NaN          NaN             NaN
# zuni             Y  NaN  NaN       NaN          NaN             NaN
# zygomatic      NaN  NaN  NaN        C4          NaN             NaN
# zygomorphic    NaN  NaN  NaN        C4          NaN             NaN
# zygosity       NaN  NaN  NaN        C4          NaN             NaN
# zygote         NaN  NaN  NaN        C1           C3             NaN
# zygotic        NaN  NaN  NaN        C3          NaN             NaN
# émigré         NaN  NaN  NaN        C2           C2             NaN
#
#               lemmetized
# Word
# 2 - sup              NaN
# a                    NaN
# aback                NaN
# abacus               NaN
# abalone              NaN
# abandon              NaN
# abandonment          NaN
# abase                NaN
# abash                NaN
# abate                NaN
# abatement            NaN
# abattoir             NaN
# abaya                NaN
# abbacy               NaN
# abbess               NaN
# abbey                NaN
# abbot                NaN
# abbreviate           NaN
# abbreviation         NaN
# abdicate             NaN
# abdication           NaN
# abdomen              NaN
# abdominal            NaN
# abduct               NaN
# abduction            NaN
# ...                  ...
# zirconia             NaN
# zither               NaN
# zloty                NaN
# zodiac               NaN
# zombie               NaN
# zonal                NaN
# zonation             NaN
# zone                 NaN
# zoo                  NaN
# zookeeper            NaN
# zoological           NaN
# zoologist            NaN
# zoology              NaN
# zoom                 NaN
# zoonotic             NaN
# zooplankton          NaN
# zucchini             NaN
# zulu                 NaN
# zuni                 NaN
# zygomatic            NaN
# zygomorphic          NaN
# zygosity             NaN
# zygote               NaN
# zygotic              NaN
# émigré               NaN
#
# [32773 rows x 12 columns]

# %% [markdown]
# ## NDL

# %%
ndl_df = pd.read_csv('../words_refined/bsl_with_lemmas.csv', index_col='Word')
ndl_df = ndl_df.drop(columns='Lemmas')
ndl_df['bsl'] = 'Y'
ndl_df.index = ndl_df.index.str.lower()

words_df = pd.concat([words_df, ndl_df[~ndl_df.index.isin(words_df.index)]])
words_df.update(ndl_df)
words_df.sort_index(inplace=True)

n = words_df[words_df['bsl'] == 'Y']

# get rid of NaN
words_df = words_df[words_df.index.notnull()]
ndl_df
words_df

# %% [markdown]
# ## Cleanup

# %%
# NaN값 채우기
words_df.oxford_level = words_df.oxford_level.fillna('NN')
words_df.oxford_version = words_df.oxford_version.fillna(0).astype(int)
words_df.lexile_grade = words_df.lexile_grade.fillna(0).astype(int)
words_df.lexile_category = words_df.lexile_category.fillna('NN')
words_df.awsl = words_df.awsl.fillna('N')
words_df.toefl = words_df.toefl.fillna('N')
words_df.tsl = words_df.tsl.fillna('N')
words_df.bsl = words_df.bsl.fillna('N')
words_df.ngsl_freq = words_df.ngsl_freq.fillna('NN')
words_df.ngsl_sp_freq = words_df.ngsl_sp_freq.fillna('NN')

# to lower (just in case)
words_df.index = words_df.index.str.lower()
words_df.sort_index(inplace=True)
# delete words containing numbers
words_df = words_df[~words_df.index.str.contains('\d')]

words_df
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                      NN               0             0              NN    Y
# aback                  NN               0             0              NN    N
# abacus                 NN               0             0              NN    N
# abalone                NN               0             0              NN    N
# abandon                B2            3000             0              NN    N
# abandonment            NN               0             0              NN    N
# abase                  NN               0             0              NN    N
# abash                  NN               0             0              NN    N
# abate                  NN               0             0              NN    N
# abatement              NN               0             0              NN    N
# abattoir               NN               0             0              NN    N
# abaya                  NN               0             0              NN    N
# abbacy                 NN               0             0              NN    N
# abbess                 NN               0             0              NN    N
# abbey                  NN               0             0              NN    N
# abbot                  NN               0             9  social_studies    N
# abbreviate             NN               0             9         general    N
# abbreviation           NN               0             6         general    N
# abdicate               NN               0             9  social_studies    N
# abdication             NN               0             0              NN    N
# abdomen                NN               0             6         science    N
# abdominal              NN               0             9         science    N
# abduct                 NN               0             0              NN    N
# abduction              NN               0             0              NN    N
# abductor               NN               0             0              NN    N
# ...                   ...             ...           ...             ...  ...
# zirconia               NN               0             0              NN    N
# zither                 NN               0             0              NN    N
# zloty                  NN               0             0              NN    N
# zodiac                 NN               0             0              NN    N
# zombie                 NN               0             0              NN    N
# zonal                  NN               0             0              NN    N
# zonation               NN               0             0              NN    N
# zone                   B2            3000             2         science    Y
# zoo                    NN               0             0              NN    N
# zookeeper              NN               0             0              NN    N
# zoological             NN               0             0              NN    N
# zoologist              NN               0             5         science    N
# zoology                NN               0             0              NN    N
# zoom                   NN               0             0              NN    N
# zoonotic               NN               0             0              NN    N
# zooplankton            NN               0             9         science    N
# zucchini               NN               0             0              NN    N
# zulu                   NN               0             9  social_studies    N
# zuni                   NN               0             0              NN    N
# zygomatic              NN               0             0              NN    N
# zygomorphic            NN               0             0              NN    N
# zygosity               NN               0             0              NN    N
# zygote                 NN               0             6         science    N
# zygotic                NN               0             0              NN    N
# émigré                 NN               0             0              NN    N
#
#              toefl tsl bsl ngsl_freq ngsl_sp_freq  naver_priority  lemmetized
# Word
# a                N   N   N        A1           A1             NaN         NaN
# aback            N   N   N        B3           C1             NaN         NaN
# abacus           N   N   N        C3           C3             NaN         NaN
# abalone          N   N   N        C3           NN             NaN         NaN
# abandon          N   N   N        A2           A3             NaN         NaN
# abandonment      N   N   N        B3           C1             NaN         NaN
# abase            N   N   N        C4           NN             NaN         NaN
# abash            N   N   N        C4           NN             NaN         NaN
# abate            N   N   N        C1           C1             NaN         NaN
# abatement        N   N   N        C1           C3             NaN         NaN
# abattoir         N   N   N        C2           C2             NaN         NaN
# abaya            N   N   N        C5           C2             NaN         NaN
# abbacy           N   N   N        C4           NN             NaN         NaN
# abbess           N   N   N        C3           NN             NaN         NaN
# abbey            N   N   N        B3           C1             NaN         NaN
# abbot            N   N   N        C1           C3             NaN         NaN
# abbreviate       Y   N   N        B3           C1             NaN         NaN
# abbreviation     Y   N   N        B3           C1             NaN         NaN
# abdicate         N   N   N        C1           C1             NaN         NaN
# abdication       N   N   N        C2           C2             NaN         NaN
# abdomen          Y   N   N        B3           B3             NaN         NaN
# abdominal        N   N   N        A4           A4             NaN         NaN
# abduct           N   N   N        B3           B2             NaN         NaN
# abduction        N   N   N        C1           B3             NaN         NaN
# abductor         N   N   N        C3           C2             NaN         NaN
# ...            ...  ..  ..       ...          ...             ...         ...
# zirconia         N   N   N        C4           NN             NaN         NaN
# zither           N   N   N        C3           C2             NaN         NaN
# zloty            N   N   N        C3           NN             NaN         NaN
# zodiac           N   N   N        C2           NN             NaN         NaN
# zombie           N   N   N        C1           C1             NaN         NaN
# zonal            N   N   N        C3           NN             NaN         NaN
# zonation         N   N   N        C5           NN             NaN         NaN
# zone             N   N   N        A3           A2             NaN         NaN
# zoo              Y   Y   N        A4           B1             NaN         NaN
# zookeeper        N   N   N        C3           C1             NaN         NaN
# zoological       N   N   N        C3           NN             NaN         NaN
# zoologist        N   N   N        C2           C3             NaN         NaN
# zoology          Y   N   N        C2           C2             NaN         NaN
# zoom             N   N   N        B2           B2             NaN         NaN
# zoonotic         N   N   N        C4           NN             NaN         NaN
# zooplankton      N   N   N        C4           NN             NaN         NaN
# zucchini         N   N   N        C2           C1             NaN         NaN
# zulu             N   N   N        NN           NN             NaN         NaN
# zuni             Y   N   N        NN           NN             NaN         NaN
# zygomatic        N   N   N        C4           NN             NaN         NaN
# zygomorphic      N   N   N        C4           NN             NaN         NaN
# zygosity         N   N   N        C4           NN             NaN         NaN
# zygote           N   N   N        C1           C3             NaN         NaN
# zygotic          N   N   N        C3           NN             NaN         NaN
# émigré           N   N   N        C2           C2             NaN         NaN
#
# [32772 rows x 12 columns]

# %% [markdown]
# ## Special Words (Compound, Characters)

# %% [markdown]
# ### Add Compound Words

# %%
# words with symbols
ex = words_df[words_df.index.str.contains("[^a-zA-Z]")]
ex

entire_lemmas = pd.read_csv('../final_datasets/entire_lemmas_complete.csv', index_col='Word')


# spaced, dashed words => unify to hyphen
spaced = words_df[words_df.index.str.contains(" ", regex=False)]
dashed = words_df[words_df.index.str.contains("-")]
compounds = spaced.append(dashed)
compounds

# ice cream
compounds.at['ice-cream', 'tsl'] = 'Y'
compounds.at['ice-cream', 'oxford_level'] = 'A1'
compounds.at['ice-cream', 'oxford_version'] = 3000
compounds = compounds.drop('ice cream')
compounds.sort_index()

# For all compound words, unify to hyphenated
def hyphenate(word):
  split = word.split()
  if len(split) == 2:
      hyphen_word = f'{split[0]}-{split[1]}'
      return hyphen_word
  return word
compounds.index = compounds.index.map(hyphenate)
compounds

# Do the same for actual words list
words_df.at['ice-cream', 'tsl'] = 'Y'
words_df.at['ice-cream', 'oxford_level'] = 'A1'
words_df.at['ice-cream', 'oxford_version'] = 3000
words_df = words_df.drop('ice cream')
words_df.sort_index()
words_df.index = words_df.index.map(hyphenate)
words_df

# For all compound words (now hyphenated),
# add to compounds lemma list & entire lemma list
compound_lemmas = pd.DataFrame()
compound_lemmas['Word'] = compounds.index

def addCompoundLemmas(word):
  split = word.split('-')
  if len(split) == 2:
    lemmas = f'{split[0]}{split[1]};{split[0]} {split[1]};{split[0]}{split[1]}s;{split[0]} {split[1]}s'
  if len(split) == 3:
    lemmas = f'{split[0]}{split[1]}{split[2]};{split[0]} {split[1]} {split[2]};{split[0]}{split[1]}{split[2]}s;{split[0]} {split[1]} {split[2]}s'
  return lemmas

compound_lemmas['Lemmas'] = compound_lemmas['Word']
compound_lemmas['Lemmas'] = compound_lemmas['Lemmas'].apply(addCompoundLemmas)
compound_lemmas.set_index('Word', inplace=True)
compound_lemmas.sort_index(inplace=True)
compound_lemmas
compound_lemmas.rename(columns={'Lemmas': 'compound_lemmas'}, inplace=True)

# for each word in compounds, find word in entire lemmas
# if word exists, add lemmas to lemmas (check duplicate)
# if not, add word and lemmas

entire_lemmas = entire_lemmas.append(compound_lemmas)
entire_lemmas = entire_lemmas.sum(level=0)
entire_lemmas = entire_lemmas.replace([0], '')
entire_lemmas['Lemmas'] = entire_lemmas['Lemmas'] + ';' + entire_lemmas['compound_lemmas'] 
entire_lemmas = entire_lemmas.drop('compound_lemmas', axis=1)
entire_lemmas.Lemmas = entire_lemmas.Lemmas.str.strip(';').str.replace(',', ';')
entire_lemmas

compound_lemmas

# entire_lemmas.loc[['t-shirt', 'ice-cream']]
# entire_lemmas[entire_lemmas.index.isin(compound_lemmas.index)]
# words_df.loc['no one']

# compound_lemmas.to_csv('../final_datasets/compound_lemmas.csv')
# entire_lemmas.to_csv('../final_datasets/entire_lemmas_compounds.csv')
# words_df.to_csv("../final_datasets/words_data_hyphenated.csv")
# Out:
# /var/folders/qz/yv1t73k93pv_4cwl9gbygk0w0000gn/T/ipykernel_90334/1918560784.py:65: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   entire_lemmas = entire_lemmas.sum(level=0)
#                                                      compound_lemmas
# Word
# by-law                                   bylaw;by law;bylaws;by laws
# decision-making    decisionmaking;decision making;decisionmakings...
# e-book                                   ebook;e book;ebooks;e books
# et-al                                        etal;et al;etals;et als
# full-time                    fulltime;full time;fulltimes;full times
# high-profile       highprofile;high profile;highprofiles;high pro...
# ice-cream                    icecream;ice cream;icecreams;ice creams
# in-law                                   inlaw;in law;inlaws;in laws
# large-scale          largescale;large scale;largescales;large scales
# long-standing      longstanding;long standing;longstandings;long ...
# long-term                    longterm;long term;longterms;long terms
# no-one                                   noone;no one;noones;no ones
# old-fashioned      oldfashioned;old fashioned;oldfashioneds;old f...
# part-time                    parttime;part time;parttimes;part times
# short-term               shortterm;short term;shortterms;short terms
# so-called                    socalled;so called;socalleds;so calleds
# t-shirt                              tshirt;t shirt;tshirts;t shirts
# thought-provoking  thoughtprovoking;thought provoking;thoughtprov...
# used-to                              usedto;used to;usedtos;used tos
# vis-à-vis                      visàvis;vis à vis;visàviss;vis à viss
# well-being               wellbeing;well being;wellbeings;well beings
# x-ray                                        xray;x ray;xrays;x rays

# %% [markdown]
# ## Delete proper nouns (states)

# %%
states = pd.read_csv("../etc_data/us_states.csv", index_col='State')
states.index = states.index.str.lower()

words_df = words_df[~words_df.index.isin(states.index)]
# words_df.loc['abigail']

# words_df.to_csv("../final_datasets/words_data_compounds_nostates.csv")

# %% [markdown]
# ## Create Existing Lemmas List

# %%
all_lemmas = pd.read_csv('../final_datasets/entire_lemmas_complete_compounds.csv', index_col='Word')
all_lemmas

existing_lemmas = all_lemmas[all_lemmas.index.isin(words_df.index)]
existing_lemmas.sort_index(inplace=True)

# existing_lemmas.to_csv("../final_datasets/existing_lemmas_final.csv")
# Out:
# /opt/miniconda3/envs/ott2/lib/python3.9/site-packages/pandas/core/frame.py:6388: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().sort_index(

# %% [markdown]
# ## Lemmetized

# %%
words_df['lemmetized'] = words_df.index.isin(existing_lemmas.index)

words_df
# words_df[words_df['lemmetized'] == True]
# words_df.to_csv("../final_datasets/words_df_final.csv")
# Out:
#              oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                      NN               0             0              NN    Y
# aback                  NN               0             0              NN    N
# abacus                 NN               0             0              NN    N
# abalone                NN               0             0              NN    N
# abandon                B2            3000             0              NN    N
# abandonment            NN               0             0              NN    N
# abase                  NN               0             0              NN    N
# abash                  NN               0             0              NN    N
# abate                  NN               0             0              NN    N
# abatement              NN               0             0              NN    N
# abattoir               NN               0             0              NN    N
# abaya                  NN               0             0              NN    N
# abbacy                 NN               0             0              NN    N
# abbess                 NN               0             0              NN    N
# abbey                  NN               0             0              NN    N
# abbot                  NN               0             9  social_studies    N
# abbreviate             NN               0             9         general    N
# abbreviation           NN               0             6         general    N
# abdicate               NN               0             9  social_studies    N
# abdication             NN               0             0              NN    N
# abdomen                NN               0             6         science    N
# abdominal              NN               0             9         science    N
# abduct                 NN               0             0              NN    N
# abduction              NN               0             0              NN    N
# abductor               NN               0             0              NN    N
# ...                   ...             ...           ...             ...  ...
# zirconia               NN               0             0              NN    N
# zither                 NN               0             0              NN    N
# zloty                  NN               0             0              NN    N
# zodiac                 NN               0             0              NN    N
# zombie                 NN               0             0              NN    N
# zonal                  NN               0             0              NN    N
# zonation               NN               0             0              NN    N
# zone                   B2            3000             2         science    Y
# zoo                    NN               0             0              NN    N
# zookeeper              NN               0             0              NN    N
# zoological             NN               0             0              NN    N
# zoologist              NN               0             5         science    N
# zoology                NN               0             0              NN    N
# zoom                   NN               0             0              NN    N
# zoonotic               NN               0             0              NN    N
# zooplankton            NN               0             9         science    N
# zucchini               NN               0             0              NN    N
# zulu                   NN               0             9  social_studies    N
# zuni                   NN               0             0              NN    N
# zygomatic              NN               0             0              NN    N
# zygomorphic            NN               0             0              NN    N
# zygosity               NN               0             0              NN    N
# zygote                 NN               0             6         science    N
# zygotic                NN               0             0              NN    N
# émigré                 NN               0             0              NN    N
#
#              toefl tsl bsl ngsl_freq ngsl_sp_freq  naver_priority  lemmetized
# Word
# a                N   N   N        A1           A1             NaN        True
# aback            N   N   N        B3           C1             NaN       False
# abacus           N   N   N        C3           C3             NaN        True
# abalone          N   N   N        C3           NN             NaN        True
# abandon          N   N   N        A2           A3             NaN        True
# abandonment      N   N   N        B3           C1             NaN        True
# abase            N   N   N        C4           NN             NaN        True
# abash            N   N   N        C4           NN             NaN        True
# abate            N   N   N        C1           C1             NaN        True
# abatement        N   N   N        C1           C3             NaN        True
# abattoir         N   N   N        C2           C2             NaN        True
# abaya            N   N   N        C5           C2             NaN        True
# abbacy           N   N   N        C4           NN             NaN        True
# abbess           N   N   N        C3           NN             NaN        True
# abbey            N   N   N        B3           C1             NaN        True
# abbot            N   N   N        C1           C3             NaN        True
# abbreviate       Y   N   N        B3           C1             NaN        True
# abbreviation     Y   N   N        B3           C1             NaN        True
# abdicate         N   N   N        C1           C1             NaN        True
# abdication       N   N   N        C2           C2             NaN        True
# abdomen          Y   N   N        B3           B3             NaN        True
# abdominal        N   N   N        A4           A4             NaN        True
# abduct           N   N   N        B3           B2             NaN        True
# abduction        N   N   N        C1           B3             NaN        True
# abductor         N   N   N        C3           C2             NaN        True
# ...            ...  ..  ..       ...          ...             ...         ...
# zirconia         N   N   N        C4           NN             NaN        True
# zither           N   N   N        C3           C2             NaN        True
# zloty            N   N   N        C3           NN             NaN        True
# zodiac           N   N   N        C2           NN             NaN        True
# zombie           N   N   N        C1           C1             NaN        True
# zonal            N   N   N        C3           NN             NaN        True
# zonation         N   N   N        C5           NN             NaN       False
# zone             N   N   N        A3           A2             NaN        True
# zoo              Y   Y   N        A4           B1             NaN        True
# zookeeper        N   N   N        C3           C1             NaN       False
# zoological       N   N   N        C3           NN             NaN       False
# zoologist        N   N   N        C2           C3             NaN        True
# zoology          Y   N   N        C2           C2             NaN        True
# zoom             N   N   N        B2           B2             NaN        True
# zoonotic         N   N   N        C4           NN             NaN       False
# zooplankton      N   N   N        C4           NN             NaN        True
# zucchini         N   N   N        C2           C1             NaN        True
# zulu             N   N   N        NN           NN             NaN        True
# zuni             Y   N   N        NN           NN             NaN        True
# zygomatic        N   N   N        C4           NN             NaN        True
# zygomorphic      N   N   N        C4           NN             NaN       False
# zygosity         N   N   N        C4           NN             NaN       False
# zygote           N   N   N        C1           C3             NaN        True
# zygotic          N   N   N        C3           NN             NaN       False
# émigré           N   N   N        C2           C2             NaN       False
#
# [32738 rows x 12 columns]
