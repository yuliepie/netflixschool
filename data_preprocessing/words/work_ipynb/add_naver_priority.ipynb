# %%
import pandas as pd

words_df = pd.read_csv("../final_datasets/words_df_final.csv", index_col='Word')
words_df

naver_df = pd.read_csv("../priority_concat.csv", index_col="Word")
naver_df
# Out:
#               naver_priority
# Word
# a                          2
# abandon                    2
# ability                    2
# abolish                    1
# about                      2
# ...                      ...
# ice cream                  2
# login                      0
# ma'am                      1
# o'clock                    2
# repairperson               0
#
# [32061 rows x 1 columns]

# %%
words_df.update(naver_df)
words_df
# Out:
#             oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                     NN               0             0              NN    Y
# aback                 NN               0             0              NN    N
# abacus                NN               0             0              NN    N
# abalone               NN               0             0              NN    N
# abandon               B2            3000             0              NN    N
# ...                  ...             ...           ...             ...  ...
# zygomorphic           NN               0             0              NN    N
# zygosity              NN               0             0              NN    N
# zygote                NN               0             6         science    N
# zygotic               NN               0             0              NN    N
# émigré                NN               0             0              NN    N
#
# ...

# %%
missing = words_df[words_df.naver_priority.isnull()]
# missing.to_csv("../missing_priority.csv")

# %% [markdown]
# ## Add back missing ones

# %%
missing_filled = pd.read_csv("../missing_priority_filled.csv", index_col="Word")
missing_filled

words_df.update(missing_filled)
words_df.naver_priority = words_df.naver_priority.astype(int)

words_df
# Out:
#             oxford_level  oxford_version  lexile_grade lexile_category awsl  \
# Word
# a                     NN             0.0           0.0              NN    Y
# aback                 NN             0.0           0.0              NN    N
# abacus                NN             0.0           0.0              NN    N
# abalone               NN             0.0           0.0              NN    N
# abandon               B2          3000.0           0.0              NN    N
# ...                  ...             ...           ...             ...  ...
# zygomorphic           NN             0.0           0.0              NN    N
# zygosity              NN             0.0           0.0              NN    N
# zygote                NN             0.0           6.0         science    N
# zygotic               NN             0.0           0.0              NN    N
# émigré                NN             0.0           0.0              NN    N
#
# ...

# %%
# words_df.to_csv("../final_datasets/words_df_final_naver.csv")
